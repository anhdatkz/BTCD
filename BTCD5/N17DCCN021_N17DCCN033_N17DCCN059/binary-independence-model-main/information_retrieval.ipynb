# %% [markdown]
# # importing libaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from pathlib import Path
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import math

# %%
#mounting google drive in order to import data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # **loading dataset**

# %%
# param limiter => used to control number of training docs being loaded because of memory overload
limiter = 1000
def load_dataset():
  results = defaultdict(list)
  path = "/content/gdrive/MyDrive/data/HW04/documents/"
  i = 0
  for file in Path(path).iterdir():
    if i < limiter:       
      with open(file, "r") as file_open:
        results["file_name"].append(file.name)
        results["text"].append(file_open.read())
      i = i+1
    
  return pd.DataFrame(results)

# %%
data = load_dataset()

# %%
#removing .txt extension
data['file_name'] = data['file_name'].apply(lambda name: name.split(".")[0])

# %%
data.shape
# Out:
# (1000, 2)

# %%
data.head()
# Out:
#     file_name                                               text
# 0  file_10215  noise measure of lossy tunnel diode amplifier ...
# 1  file_10861  the use of probing electrodes in the study of ...
# 2  file_10982  travelling pressure waves associated with geom...
# 3  file_10952  the australian national radio astronomy observ...
# 4  file_10269  cosmic ray phenomena during the november solar...

# %%
path1 = "/content/gdrive/MyDrive/data/HW04/file_label.txt"
labels = pd.read_csv(path1, names=["file_name", "label"], sep=",", header=None)
labels.head()
# Out:
#   file_name  label
# 0    file_0      0
# 1    file_1      0
# 2    file_2      0
# 3    file_3      0
# 4    file_4      0

# %%
#removing nulls
labels["label"].fillna(0, inplace=True)
labels["label"] = labels["label"].apply(lambda label: label if label != None else 0)
#concat labels to the documents dataframe
labels = labels.reindex(index=labels.index[::-1])

# %%
labels.head()
# Out:
#         file_name  label
# 11428  file_11428      0
# 11427  file_11427      0
# 11426  file_11426      0
# 11425  file_11425      0
# 11424  file_11424      0

# %%
# labels["label"][:limiter]
# data["labels"] = labels["label"][:limiter]
data["labels"] = ""
i = 1
for file_name in data["file_name"]:
  index = data[data["file_name"] == file_name].index.values[0]
  label = labels[labels["file_name"] == file_name]["label"]
  data["labels"][index] = label.values[0] if len(label) > 0 else 0
  # print(data["labels"][data.iloc[data["file_name"] == file_name].index])
# data["labels"] = labels["label"][:limiter]
data.head()
# Out:
#     file_name                                               text labels
# 0  file_10215  noise measure of lossy tunnel diode amplifier ...      0
# 1  file_10861  the use of probing electrodes in the study of ...      0
# 2  file_10982  travelling pressure waves associated with geom...      0
# 3  file_10952  the australian national radio astronomy observ...      0
# 4  file_10269  cosmic ray phenomena during the november solar...      0

# %% [markdown]
# configs
#
# *   only necessary in google colab

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# tokenization

# %%
def tokenize(word_list):
  tokenized_text = []
  for text in word_list:
    tokenized_text.append(word_tokenize(text))
  return tokenized_text
data["text"] = list(tokenize(data["text"]))

# %%
data.head()
# Out:
#     file_name                                               text labels
# 0  file_10215  [noise, measure, of, lossy, tunnel, diode, amp...      0
# 1  file_10861  [the, use, of, probing, electrodes, in, the, s...      0
# 2  file_10982  [travelling, pressure, waves, associated, with...      0
# 3  file_10952  [the, australian, national, radio, astronomy, ...      0
# 4  file_10269  [cosmic, ray, phenomena, during, the, november...      0

# %% [markdown]
# change case to lower case

# %%
data['text'] = data['text'].apply(lambda list: [txt.lower() for txt in list])
data.head()
# Out:
#     file_name                                               text labels
# 0  file_10215  [noise, measure, of, lossy, tunnel, diode, amp...      0
# 1  file_10861  [the, use, of, probing, electrodes, in, the, s...      0
# 2  file_10982  [travelling, pressure, waves, associated, with...      0
# 3  file_10952  [the, australian, national, radio, astronomy, ...      0
# 4  file_10269  [cosmic, ray, phenomena, during, the, november...      0

# %% [markdown]
# stop word removal

# %%
stop_words = set(stopwords.words('english'))
data['text'] = data['text'].apply(lambda list: [txt for txt in list if not txt in stop_words])
data.head()
# Out:
#     file_name                                               text labels
# 0  file_10215  [noise, measure, lossy, tunnel, diode, amplifi...      0
# 1  file_10861  [use, probing, electrodes, study, ionosphere, ...      0
# 2  file_10982  [travelling, pressure, waves, associated, geom...      0
# 3  file_10952  [australian, national, radio, astronomy, obser...      0
# 4  file_10269  [cosmic, ray, phenomena, november, solar, dist...      0

# %% [markdown]
# stemming

# %%
porter_stemmer = PorterStemmer()
data['text'] = data['text'].apply(lambda list: [porter_stemmer.stem(txt) for txt in list])
data.head()
# Out:
#     file_name                                               text labels
# 0  file_10215  [nois, measur, lossi, tunnel, diod, amplifi, s...      0
# 1  file_10861  [use, probe, electrod, studi, ionospher, measu...      0
# 2  file_10982  [travel, pressur, wave, associ, geomagnet, act...      0
# 3  file_10952  [australian, nation, radio, astronomi, observa...      0
# 4  file_10269  [cosmic, ray, phenomena, novemb, solar, distur...      0

# %% [markdown]
# ### **generating an inverted index of terms**
# here we are going to create a dictionary with all words as keys and the values are the doc file names containing the word
# *   *NOTE: The get_inverted_index function is memory and cpu intensive so it may take some time*

# %%
#first we get all words
wordlist = [txt for list in data['text'] for txt in list]
#get only unique values using set
wordlist = set(wordlist)
wordlist = list(wordlist)
wordlist
# Out:
# ['transient',
#  'elast',
#  'mz',
#  'planar',
#  'uncoupl',
#  'thermospher',
#  'al',
#  'calcul',
#  'tie',
#  'suffici',
#  'procedur',
#  'archipelago',
#  'dsb',
#  'immedi',
#  'unfocus',
#  'concentr',
#  'maxwel',
#  'beta',
#  'subtract',
#  'labori',
#  'power',
#  'integ',
#  'juli',
#  'prebunch',
#  'address',
#  'zone',
#  'discret',
#  'upon',
#  'tl',
#  'circumst',
#  'lf',
#  'piec',
#  'unidirect',
#  'portion',
#  'mention',
#  'group',
#  'multipli',
#  'review',
#  'express',
#  'tempor',
#  'magnon',
#  'around',
#  'withou',
#  'form',
#  'design',
#  'receiv',
#  'driven',
#  'conjunct',
#  'batteri',
#  'striplin',
#  'deriv',
#  'commut',
#  'inter',
#  'adjoin',
#  'take',
#  'infin',
#  'cathod',
#  'binari',
#  'whisper',
#  'ultrason',
#  'abl',
#  'english',
#  'durat',
#  'magnetostrict',
#  'similar',
#  'possibl',
#  'text',
#  'follow',
#  'demonstr',
#  'amplifi',
#  'seriou',
#  'discover',
#  'spheric',
#  'potenti',
#  'sponsor',
#  'withstand',
#  'lesser',
#  'cluster',
#  'invari',
#  'thermodynam',
#  'manufactur',
#  'reflect',
#  'incid',
#  'maximum',
#  'alkalin',
#  'lead',
#  'magneto',
#  'hobart',
#  'seen',
#  'autocorrel',
#  'static',
#  'cascad',
#  'ozon',
#  'schmitt',
#  'emerg',
#  'slough',
#  'ionogram',
#  'terr',
#  'due',
#  'filamentari',
#  'proportion',
#  'pictur',
#  'shape',
#  'failur',
#  'residu',
#  'seeger',
#  'exterior',
#  'schedul',
#  'next',
#  'success',
#  'per',
#  'phonon',
#  'present',
#  'decametr',
#  'mean',
#  'stormi',
#  'frequent',
#  'height',
#  'trigger',
#  'gravit',
#  'littl',
#  'toler',
#  'bott',
#  'hyperfin',
#  'ellips',
#  'mesospher',
#  'corpuscular',
#  'twice',
#  'heavi',
#  'striat',
#  'celoscop',
#  'balanc',
#  'wave',
#  'stray',
#  'incoher',
#  'technic',
#  'indic',
#  'ephi',
#  'sreen',
#  'anc',
#  'japan',
#  'overtak',
#  'em',
#  'dealt',
#  'occult',
#  'visibl',
#  'environment',
#  'linearli',
#  'optoelectron',
#  'interfer',
#  'deplet',
#  'nerv',
#  'origin',
#  'recognit',
#  'impuls',
#  'solid',
#  'catalogu',
#  'logic',
#  'minneapoli',
#  'dimension',
#  'nonsymmetr',
#  'antenna',
#  'strike',
#  'sputnik',
#  'tube',
#  'featur',
#  'munich',
#  'e',
#  'perman',
#  'servo',
#  'provid',
#  'latch',
#  'publish',
#  'electrodynam',
#  'excit',
#  'shown',
#  'end',
#  'shower',
#  'gyrat',
#  'greenland',
#  'envelop',
#  'refract',
#  'colleg',
#  'tend',
#  'thyratron',
#  'adiabat',
#  'condit',
#  'changer',
#  'lose',
#  'ion',
#  'monthli',
#  'cygnu',
#  'econom',
#  'dissip',
#  'underestim',
#  'ia',
#  'cro',
#  'irregular',
#  'liquid',
#  'centr',
#  'magnetostat',
#  'gase',
#  'sho',
#  'tabul',
#  'onset',
#  'numer',
#  'unequ',
#  'mixer',
#  'compu',
#  'clearest',
#  'ray',
#  'peltier',
#  'comprehens',
#  'reject',
#  'opposit',
#  'ezrth',
#  'corpuscl',
#  'construct',
#  'sequenc',
#  'poona',
#  'apoge',
#  'wheatston',
#  'photograph',
#  'impur',
#  'axi',
#  'coupl',
#  'replac',
#  'compat',
#  'ho',
#  'orient',
#  'alway',
#  'algebra',
#  'damag',
#  'arriv',
#  'suppli',
#  'nonreact',
#  'winter',
#  'radio',
#  'aspect',
#  'hopf',
#  'diod',
#  'stockholm',
#  'nigeria',
#  'troposcatt',
#  'profil',
#  'card',
#  'exactli',
#  'three',
#  'spread',
#  'fall',
#  'predict',
#  'meteoroid',
#  'sector',
#  'riomet',
#  'relax',
#  'bound',
#  'valv',
#  'mani',
#  'sine',
#  'md',
#  'analyt',
#  'tantalum',
#  'extens',
#  'horizont',
#  'stimul',
#  'quantum',
#  'fade',
#  'state',
#  'surfac',
#  'scatter',
#  'declin',
#  'radar',
#  'identifi',
#  'telecommun',
#  'ith',
#  'scan',
#  'sharpli',
#  'bureau',
#  'ideal',
#  'involv',
#  'boltzmann',
#  'adder',
#  'movement',
#  'devic',
#  'becom',
#  'gaseou',
#  'boxcar',
#  'maryn',
#  'pnpn',
#  'radiometr',
#  'uptap',
#  'oxygen',
#  'stand',
#  'semiannu',
#  'nonrealiz',
#  'half',
#  'sodankyla',
#  'paramet',
#  'hot',
#  'seven',
#  'banalor',
#  'panel',
#  'imperfect',
#  'adopt',
#  'write',
#  'bear',
#  'lindau',
#  'amount',
#  'pure',
#  'reproduc',
#  'radioact',
#  'satisfactori',
#  'neuristor',
#  'overcom',
#  'implic',
#  'exceed',
#  'sun',
#  'comput',
#  'oxid',
#  'ultraviolet',
#  'johnson',
#  'nord',
#  'especi',
#  'equival',
#  'ew',
#  'uncertainti',
#  'jacobi',
#  'mere',
#  'photospher',
#  'radial',
#  'period',
#  'ferrit',
#  'lifetim',
#  'martyn',
#  'spacecraft',
#  'heat',
#  'anomali',
#  'add',
#  'ledg',
#  'oblat',
#  'given',
#  'smooth',
#  'tensor',
#  'might',
#  'recomput',
#  'lump',
#  'raman',
#  'taper',
#  'percentag',
#  'pass',
#  'coverag',
#  'radiu',
#  'list',
#  'interact',
#  'find',
#  'goldstein',
#  'sphere',
#  'wideband',
#  'synchrotron',
#  'nonvanish',
#  'laboratori',
#  'former',
#  'outer',
#  'stage',
#  'modif',
#  'morn',
#  'ordin',
#  'relev',
#  'philadelphia',
#  'issu',
#  'tail',
#  'merit',
#  'rumi',
#  'geomagnet',
#  'u',
#  'optim',
#  'tool',
#  'wide',
#  'interband',
#  'imag',
#  'collid',
#  'geometri',
#  'astrophys',
#  'singli',
#  'drum',
#  'block',
#  'septemb',
#  'asymmetri',
#  'incident',
#  'climatolog',
#  'mode',
#  'unexpect',
#  'varactor',
#  'breakdown',
#  'fermi',
#  'cw',
#  'p',
#  'improv',
#  'analys',
#  'second',
#  'transmit',
#  'split',
#  'dissoci',
#  'ocean',
#  'lunisolar',
#  'tightli',
#  'geophys',
#  'electrostat',
#  'sputter',
#  'continuum',
#  'accomplish',
#  'tamal',
#  'fatigu',
#  'octav',
#  'weak',
#  'similitud',
#  'campbel',
#  'outermost',
#  'gate',
#  'variabl',
#  'potentiomet',
#  'circul',
#  'possess',
#  'essenti',
#  'demodul',
#  'window',
#  'brigg',
#  'nitrogen',
#  'relationship',
#  'transfluxor',
#  'voltag',
#  'begin',
#  'entri',
#  'underli',
#  'increment',
#  'simul',
#  'corbino',
#  'geolog',
#  'type',
#  'overhead',
#  'italian',
#  'mm',
#  'seem',
#  'round',
#  'net',
#  'kirchhoff',
#  'releas',
#  'shhsrropos',
#  'pulkov',
#  'ascrib',
#  'kemp',
#  'constitut',
#  'bombard',
#  'dip',
#  'extraordinari',
#  'univers',
#  'current',
#  'partit',
#  'late',
#  'proof',
#  'practic',
#  'shadow',
#  'horn',
#  'centimetr',
#  'helitran',
#  'node',
#  'ambient',
#  'togeth',
#  'wien',
#  'storm',
#  'connect',
#  'departur',
#  'bonn',
#  'plane',
#  'quadratur',
#  'strong',
#  'go',
#  'emiss',
#  'metal',
#  'extragalact',
#  'techniqu',
#  'certain',
#  'reactiv',
#  'novaya',
#  'davi',
#  'multist',
#  'perfor',
#  'simpler',
#  'oslo',
#  'correl',
#  'kaenel',
#  'bloch',
#  'occur',
#  'crochet',
#  'superior',
#  'set',
#  'mesa',
#  'ba',
#  'metr',
#  'afbmd',
#  'may',
#  'accur',
#  'yield',
#  'cylindr',
#  'strongli',
#  'diagram',
#  'splot',
#  'reaction',
#  'weather',
#  'contact',
#  'stop',
#  'martin',
#  'simplifi',
#  'get',
#  'interpret',
#  'interv',
#  'scale',
#  'prior',
#  'alon',
#  'gross',
#  'shock',
#  'inadequ',
#  'materi',
#  'isotop',
#  'enhanc',
#  'unaffect',
#  'enumer',
#  'descript',
#  'sub',
#  'luminos',
#  'complic',
#  'intrins',
#  'experiment',
#  'hundredth',
#  'constant',
#  'sheath',
#  'futur',
#  'synthes',
#  'signatur',
#  'achiev',
#  'stablein',
#  'ottawa',
#  'phon',
#  'deceler',
#  'first',
#  'azimuth',
#  'rigor',
#  'faraday',
#  'middl',
#  'event',
#  'repeat',
#  'media',
#  'error',
#  'explos',
#  'video',
#  'chromospher',
#  'joint',
#  'defin',
#  'work',
#  'wate',
#  'shell',
#  'masur',
#  'lock',
#  'creation',
#  'electr',
#  'runaway',
#  'locat',
#  'chang',
#  'memori',
#  'sh',
#  'branch',
#  'travel',
#  'bit',
#  'master',
#  'capabl',
#  'qualiti',
#  'leve',
#  'toroid',
#  'summar',
#  'assumpt',
#  'trigonometr',
#  'convers',
#  'dens',
#  'recurr',
#  'concurr',
#  'solut',
#  'philip',
#  'air',
#  'striae',
#  'posit',
#  'driver',
#  'introduct',
#  'ioniz',
#  'fluctuat',
#  'emphas',
#  'fernando',
#  'neutron',
#  'govern',
#  'suppress',
#  'restrict',
#  'associ',
#  'fring',
#  'vortic',
#  'matric',
#  'board',
#  'spectroscopi',
#  'threse',
#  'fokker',
#  'sansserif',
#  'annular',
#  'brewster',
#  'out',
#  'inner',
#  'season',
#  'washington',
#  'uniform',
#  'neu',
#  'appropri',
#  'anisotrop',
#  'adequ',
#  'understand',
#  'quasihydrodynam',
#  'dynam',
#  'vectori',
#  'employ',
#  'flown',
#  'triod',
#  'audio',
#  'load',
#  'militari',
#  'daili',
#  'fulli',
#  'comment',
#  'unreli',
#  'ink',
#  'treat',
#  'diffract',
#  'hemispher',
#  'fraction',
#  'satisfi',
#  'perform',
#  'giten',
#  'worker',
#  'rc',
#  'emitt',
#  'shift',
#  'eleven',
#  'lain',
#  'meteor',
#  'print',
#  'quot',
#  'explor',
#  'act',
#  'evapor',
#  'lowamplitud',
#  'direct',
#  'pre',
#  'uk',
#  'map',
#  'mismatch',
#  'sky',
#  'tin',
#  'sellmey',
#  'forbush',
#  'explain',
#  'broad',
#  'chart',
#  'vp',
#  'spectromet',
#  'bomb',
#  'gap',
#  'israel',
#  'entropi',
#  'perseu',
#  'mercuri',
#  'multichannel',
#  'eigenvalu',
#  'hourli',
#  'german',
#  'probe',
#  'develop',
#  'meet',
#  'metast',
#  'apertur',
#  'key',
#  'invers',
#  'planetari',
#  'concav',
#  'denot',
#  'limit',
#  'heisenberg',
#  'artifici',
#  'preferenti',
#  'n',
#  'attain',
#  'display',
#  'semiconduct',
#  'import',
#  'larmor',
#  'russian',
#  'decay',
#  'extrapol',
#  'verifi',
#  'ball',
#  'corresspond',
#  'patch',
#  'megawatt',
#  'everi',
#  'crown',
#  'capacit',
#  'widthmm',
#  'seal',
#  'protonospher',
#  'stark',
#  'close',
#  'prescrib',
#  'analysi',
#  'dimensionless',
#  'tidal',
#  'antarct',
#  'effici',
#  'significantli',
#  'sudden',
#  'wavelength',
#  'box',
#  'san',
#  'adjust',
#  'connexion',
#  'sever',
#  'capetown',
#  'subsequ',
#  'aerial',
#  'rutil',
#  'determin',
#  'launch',
#  'diffus',
#  'concern',
#  'criterion',
#  'ionic',
#  'compris',
#  'ambipolar',
#  'irradi',
#  'ascens',
#  'vast',
#  'acceler',
#  'sinc',
#  'vapour',
#  'unwat',
#  'piggott',
#  'nuclei',
#  'genoa',
#  'reiter',
#  'rarefi',
#  'guidanc',
#  'pair',
#  'toward',
#  'microbarograph',
#  'mutual',
#  'polish',
#  'electrojet',
#  'low',
#  'hf',
#  'serv',
#  'exp',
#  'past',
#  'infrar',
#  'deal',
#  'instantan',
#  'substanti',
#  'infrequ',
#  'whose',
#  'multipol',
#  'plasma',
#  'tape',
#  'observatori',
#  'output',
#  'reactanc',
#  'summat',
#  'suscept',
#  'topsid',
#  'electrohydromagnet',
#  'track',
#  'detect',
#  'nonessenti',
#  'veroniqu',
#  'peak',
#  'introduc',
#  'composit',
#  'linear',
#  'rang',
#  'storag',
#  'represent',
#  'filament',
#  'nondevi',
#  'part',
#  'exhibit',
#  'estim',
#  'ngc',
#  'megaton',
#  'dope',
#  'leakag',
#  'sec',
#  'straight',
#  'configur',
#  'australian',
#  'baker',
#  'academi',
#  'scienc',
#  'fix',
#  'forc',
#  'infinitesim',
#  'reson',
#  'aurora',
#  'version',
#  'loop',
#  'author',
#  'magic',
#  'coat',
#  'miller',
#  'oscillogram',
#  'polar',
#  'accuraci',
#  'deby',
#  'record',
#  'unz',
#  'geometr',
#  'character',
#  'project',
#  'log',
#  'refriger',
#  'persist',
#  'small',
#  'diamagnet',
#  'stratum',
#  'annul',
#  'dumb',
#  'data',
#  'circuitri',
#  'ward',
#  'via',
#  'deflect',
#  'decemb',
#  'millimetr',
#  'kokobunji',
#  'nyquist',
#  'ghana',
#  'angl',
#  'infer',
#  'harmon',
#  'diminish',
#  'diatom',
#  'rod',
#  'increas',
#  'nebula',
#  'focus',
#  'control',
#  'million',
#  'reactor',
#  'field',
#  'distort',
#  'arc',
#  'assembl',
#  'greatest',
#  'tsumeb',
#  'instal',
#  'converg',
#  'experi',
#  'planet',
#  'explicit',
#  'strip',
#  'lie',
#  'allen',
#  'inadequaci',
#  'union',
#  'plate',
#  'astabl',
#  'unilater',
#  'convect',
#  'build',
#  'meta',
#  'allow',
#  'perpendicular',
#  'g',
#  'id',
#  'slightli',
#  'mill',
#  'fluid',
#  'chamber',
#  'spitzer',
#  'common',
#  'passag',
#  'script',
#  'zeta',
#  'bidirect',
#  'maxima',
#  'thermonuclear',
#  'transformerless',
#  'trigonometri',
#  'barium',
#  'report',
#  'view',
#  'electromechan',
#  'relat',
#  'cone',
#  'neutral',
#  'bremsstrahlung',
#  'inaugur',
#  'activ',
#  'diagnost',
#  'strain',
#  'northward',
#  'enough',
#  'larg',
#  'argu',
#  'bias',
#  'natur',
#  'rectifi',
#  'arctic',
#  'decim',
#  'head',
#  'knowledg',
#  'mid',
#  'virtual',
#  'input',
#  'disadvantag',
#  'slight',
#  'proceed',
#  'emf',
#  'ellipsoid',
#  'typic',
#  'bandyopadhyay',
#  'unprotect',
#  'rico',
#  'godley',
#  'nonblanket',
#  'hydromagnet',
#  'often',
#  'l',
#  'ssc',
#  'invalid',
#  'paper',
#  'move',
#  'neumann',
#  'affect',
#  'confer',
#  'would',
#  'examin',
#  'recoveri',
#  'flip',
#  'grade',
#  'microwav',
#  'degrad',
#  'side',
#  'hall',
#  'live',
#  'shaft',
#  'music',
#  'appendic',
#  'properti',
#  'abil',
#  'nonrevers',
#  'even',
#  'area',
#  'collis',
#  'highest',
#  'parker',
#  'hamiltonian',
#  'delay',
#  'dualiti',
#  'start',
#  'bunch',
#  'byrn',
#  'bright',
#  'decreas',
#  'ten',
#  'longitud',
#  'overlap',
#  'africa',
#  'insid',
#  'asiago',
#  'rarifi',
#  'tripl',
#  'veloc',
#  'soviet',
#  'lowest',
#  'stainless',
#  'offset',
#  'edg',
#  'preamplifi',
#  'metaast',
#  'februari',
#  'minimum',
#  'thick',
#  'summer',
#  'jupit',
#  'doppler',
#  'geocyclotron',
#  'lecher',
#  'applic',
#  'element',
#  ...]

# %%
def get_inverted_index():
  word_dict = defaultdict(set)  
  for i, doc in enumerate(data['text']):
    for word in wordlist:
      if word in doc:
        word_dict[word].add(data.iloc[i, 0])
  return word_dict

word_dict = get_inverted_index()
# word_dict = pd.DataFrame(get_inverted_index())
# word_dict.head()
word_dict
# Out:
# defaultdict(set,
#             {'calcul': {'file_10009',
#               'file_10032',
#               'file_10053',
#               'file_10072',
#               'file_10077',
#               'file_10087',
#               'file_10107',
#               'file_10117',
#               'file_10124',
#               'file_10125',
#               'file_10135',
#               'file_10146',
#               'file_10215',
#               'file_10221',
#               'file_10228',
#               'file_10235',
#               'file_10240',
#               'file_10242',
#               'file_10244',
#               'file_10250',
#               'file_10268',
#               'file_10286',
#               'file_10290',
#               'file_10388',
#               'file_10431',
#               'file_10444',
#               'file_10484',
#               'file_10485',
#               'file_10528',
#               'file_10579',
#               'file_10588',
#               'file_10681',
#               'file_10713',
#               'file_10770',
#               'file_10772',
#               'file_10853',
#               'file_10862',
#               'file_10887',
#               'file_10911',
#               'file_10919',
#               'file_10920',
#               'file_10921',
#               'file_10937',
#               'file_10948',
#               'file_10970',
#               'file_11040',
#               'file_11065',
#               'file_11097',
#               'file_11107',
#               'file_11118',
#               'file_11120',
#               'file_11131',
#               'file_11189',
#               'file_11213',
#               'file_11238',
#               'file_11289',
#               'file_11302',
#               'file_11325',
#               'file_11344',
#               'file_11387'},
#              'amplifi': {'file_10033',
#               'file_10043',
#               'file_10044',
#               'file_10052',
#               'file_10053',
#               'file_10055',
#               'file_10056',
#               'file_10061',
#               'file_10065',
#               'file_10066',
#               'file_10153',
#               'file_10192',
#               'file_10193',
#               'file_10194',
#               'file_10195',
#               'file_10196',
#               'file_10197',
#               'file_10200',
#               'file_10203',
#               'file_10204',
#               'file_10205',
#               'file_10206',
#               'file_10207',
#               'file_10208',
#               'file_10213',
#               'file_10215',
#               'file_10218',
#               'file_10329',
#               'file_10363',
#               'file_10364',
#               'file_10365',
#               'file_10369',
#               'file_10370',
#               'file_10373',
#               'file_10375',
#               'file_10376',
#               'file_10473',
#               'file_10504',
#               'file_10505',
#               'file_10506',
#               'file_10507',
#               'file_10509',
#               'file_10511',
#               'file_10512',
#               'file_10514',
#               'file_10516',
#               'file_10635',
#               'file_10636',
#               'file_10637',
#               'file_10639',
#               'file_10640',
#               'file_10642',
#               'file_10764',
#               'file_10765',
#               'file_10767',
#               'file_10768',
#               'file_10769',
#               'file_10774',
#               'file_10776',
#               'file_10809',
#               'file_10897',
#               'file_10898',
#               'file_10900',
#               'file_10901',
#               'file_11039',
#               'file_11054',
#               'file_11060',
#               'file_11061',
#               'file_11062',
#               'file_11063',
#               'file_11188',
#               'file_11203',
#               'file_11208',
#               'file_11301',
#               'file_11325',
#               'file_11329',
#               'file_11330',
#               'file_11333',
#               'file_11334',
#               'file_11335',
#               'file_11336',
#               'file_11352'},
#              'diod': {'file_10025',
#               'file_10046',
#               'file_10047',
#               'file_10051',
#               'file_10065',
#               'file_10066',
#               'file_10070',
#               'file_10155',
#               'file_10184',
#               'file_10208',
#               'file_10213',
#               'file_10214',
#               'file_10215',
#               'file_10218',
#               'file_10219',
#               'file_10320',
#               'file_10326',
#               'file_10343',
#               'file_10350',
#               'file_10353',
#               'file_10373',
#               'file_10376',
#               'file_10464',
#               'file_10466',
#               'file_10495',
#               'file_10500',
#               'file_10516',
#               'file_10615',
#               'file_10616',
#               'file_10640',
#               'file_10734',
#               'file_10737',
#               'file_10745',
#               'file_10758',
#               'file_10760',
#               'file_10774',
#               'file_10776',
#               'file_10777',
#               'file_10778',
#               'file_10884',
#               'file_10890',
#               'file_10898',
#               'file_10901',
#               'file_10902',
#               'file_11022',
#               'file_11060',
#               'file_11194',
#               'file_11288',
#               'file_11291',
#               'file_11301',
#               'file_11333',
#               'file_11336'},
#              'stage': {'file_10192',
#               'file_10205',
#               'file_10213',
#               'file_10215',
#               'file_10364',
#               'file_10369',
#               'file_10447',
#               'file_10516',
#               'file_10635',
#               'file_10757',
#               'file_10767',
#               'file_11164',
#               'file_11171',
#               'file_11336'},
#              'repeat': {'file_10019',
#               'file_10215',
#               'file_10460',
#               'file_11428'},
#              'loss': {'file_10215',
#               'file_10298',
#               'file_10445',
#               'file_10486',
#               'file_10617',
#               'file_10780',
#               'file_10795',
#               'file_10804',
#               'file_10874',
#               'file_11040',
#               'file_11144',
#               'file_11316',
#               'file_11323',
#               'file_11405',
#               'file_11408'},
#              'influenc': {'file_10205',
#               'file_10215',
#               'file_10255',
#               'file_10286',
#               'file_10313',
#               'file_10654',
#               'file_10786',
#               'file_10842',
#               'file_10850',
#               'file_10857',
#               'file_10911',
#               'file_10928',
#               'file_10981',
#               'file_10986',
#               'file_11085',
#               'file_11158',
#               'file_11357',
#               'file_11394'},
#              'tunnel': {'file_10046',
#               'file_10047',
#               'file_10051',
#               'file_10155',
#               'file_10184',
#               'file_10215',
#               'file_10326',
#               'file_10343',
#               'file_10350',
#               'file_10353',
#               'file_10376',
#               'file_10495',
#               'file_10516',
#               'file_10616',
#               'file_10737',
#               'file_10760',
#               'file_10776',
#               'file_10778',
#               'file_10901',
#               'file_10902',
#               'file_11022',
#               'file_11194',
#               'file_11291',
#               'file_11301',
#               'file_11336'},
#              'circuit': {'file_10022',
#               'file_10025',
#               'file_10026',
#               'file_10032',
#               'file_10035',
#               'file_10037',
#               'file_10044',
#               'file_10046',
#               'file_10047',
#               'file_10048',
#               'file_10049',
#               'file_10050',
#               'file_10051',
#               'file_10053',
#               'file_10150',
#               'file_10153',
#               'file_10161',
#               'file_10163',
#               'file_10167',
#               'file_10168',
#               'file_10171',
#               'file_10182',
#               'file_10189',
#               'file_10194',
#               'file_10197',
#               'file_10204',
#               'file_10214',
#               'file_10215',
#               'file_10216',
#               'file_10218',
#               'file_10219',
#               'file_10319',
#               'file_10320',
#               'file_10322',
#               'file_10325',
#               'file_10328',
#               'file_10330',
#               'file_10331',
#               'file_10335',
#               'file_10340',
#               'file_10342',
#               'file_10345',
#               'file_10350',
#               'file_10352',
#               'file_10355',
#               'file_10364',
#               'file_10373',
#               'file_10464',
#               'file_10478',
#               'file_10480',
#               'file_10484',
#               'file_10487',
#               'file_10494',
#               'file_10498',
#               'file_10500',
#               'file_10507',
#               'file_10516',
#               'file_10613',
#               'file_10616',
#               'file_10617',
#               'file_10618',
#               'file_10620',
#               'file_10621',
#               'file_10623',
#               'file_10625',
#               'file_10635',
#               'file_10637',
#               'file_10644',
#               'file_10698',
#               'file_10732',
#               'file_10734',
#               'file_10735',
#               'file_10737',
#               'file_10738',
#               'file_10760',
#               'file_10761',
#               'file_10771',
#               'file_10776',
#               'file_10779',
#               'file_10845',
#               'file_10872',
#               'file_10880',
#               'file_10883',
#               'file_10901',
#               'file_11022',
#               'file_11026',
#               'file_11027',
#               'file_11039',
#               'file_11044',
#               'file_11050',
#               'file_11059',
#               'file_11099',
#               'file_11163',
#               'file_11171',
#               'file_11182',
#               'file_11188',
#               'file_11189',
#               'file_11193',
#               'file_11194',
#               'file_11288',
#               'file_11290',
#               'file_11293',
#               'file_11295',
#               'file_11296',
#               'file_11301',
#               'file_11307',
#               'file_11310',
#               'file_11315',
#               'file_11321',
#               'file_11322',
#               'file_11325',
#               'file_11329',
#               'file_11330',
#               'file_11336'},
#              'nois': {'file_10033',
#               'file_10038',
#               'file_10053',
#               'file_10065',
#               'file_10066',
#               'file_10075',
#               'file_10200',
#               'file_10203',
#               'file_10204',
#               'file_10205',
#               'file_10213',
#               'file_10215',
#               'file_10263',
#               'file_10264',
#               'file_10343',
#               'file_10345',
#               'file_10369',
#               'file_10370',
#               'file_10373',
#               'file_10375',
#               'file_10376',
#               'file_10410',
#               'file_10411',
#               'file_10455',
#               'file_10460',
#               'file_10506',
#               'file_10512',
#               'file_10538',
#               'file_10541',
#               'file_10600',
#               'file_10617',
#               'file_10630',
#               'file_10692',
#               'file_10713',
#               'file_10714',
#               'file_10716',
#               'file_10727',
#               'file_10768',
#               'file_10778',
#               'file_10814',
#               'file_10882',
#               'file_10918',
#               'file_10956',
#               'file_10957',
#               'file_11002',
#               'file_11063',
#               'file_11066',
#               'file_11078',
#               'file_11153',
#               'file_11163',
#               'file_11179',
#               'file_11203',
#               'file_11211',
#               'file_11280',
#               'file_11301',
#               'file_11329',
#               'file_11333',
#               'file_11336',
#               'file_11349'},
#              'seri': {'file_10034',
#               'file_10065',
#               'file_10089',
#               'file_10127',
#               'file_10215',
#               'file_10241',
#               'file_10244',
#               'file_10359',
#               'file_10552',
#               'file_10623',
#               'file_10696',
#               'file_10750',
#               'file_10778',
#               'file_10807',
#               'file_10919',
#               'file_10941',
#               'file_11092',
#               'file_11132',
#               'file_11164',
#               'file_11248',
#               'file_11307'},
#              'measur': {'file_10013',
#               'file_10014',
#               'file_10026',
#               'file_10032',
#               'file_10034',
#               'file_10044',
#               'file_10080',
#               'file_10102',
#               'file_10120',
#               'file_10123',
#               'file_10135',
#               'file_10144',
#               'file_10151',
#               'file_10187',
#               'file_10204',
#               'file_10215',
#               'file_10218',
#               'file_10264',
#               'file_10267',
#               'file_10281',
#               'file_10287',
#               'file_10294',
#               'file_10297',
#               'file_10298',
#               'file_10299',
#               'file_10302',
#               'file_10330',
#               'file_10350',
#               'file_10376',
#               'file_10381',
#               'file_10411',
#               'file_10414',
#               'file_10427',
#               'file_10430',
#               'file_10433',
#               'file_10439',
#               'file_10452',
#               'file_10453',
#               'file_10487',
#               'file_10506',
#               'file_10533',
#               'file_10540',
#               'file_10551',
#               'file_10552',
#               'file_10566',
#               'file_10570',
#               'file_10571',
#               'file_10574',
#               'file_10575',
#               'file_10580',
#               'file_10588',
#               'file_10591',
#               'file_10595',
#               'file_10600',
#               'file_10652',
#               'file_10673',
#               'file_10674',
#               'file_10693',
#               'file_10698',
#               'file_10713',
#               'file_10716',
#               'file_10718',
#               'file_10725',
#               'file_10727',
#               'file_10744',
#               'file_10783',
#               'file_10784',
#               'file_10787',
#               'file_10812',
#               'file_10820',
#               'file_10826',
#               'file_10836',
#               'file_10841',
#               'file_10856',
#               'file_10860',
#               'file_10861',
#               'file_10862',
#               'file_10865',
#               'file_10867',
#               'file_10872',
#               'file_10873',
#               'file_10882',
#               'file_10884',
#               'file_10931',
#               'file_10946',
#               'file_10958',
#               'file_10973',
#               'file_10979',
#               'file_10996',
#               'file_11033',
#               'file_11063',
#               'file_11078',
#               'file_11088',
#               'file_11090',
#               'file_11108',
#               'file_11125',
#               'file_11126',
#               'file_11132',
#               'file_11141',
#               'file_11146',
#               'file_11160',
#               'file_11203',
#               'file_11207',
#               'file_11217',
#               'file_11242',
#               'file_11247',
#               'file_11249',
#               'file_11259',
#               'file_11260',
#               'file_11269',
#               'file_11289',
#               'file_11299',
#               'file_11359',
#               'file_11392',
#               'file_11411',
#               'file_11415',
#               'file_11419',
#               'file_11420'},
#              'consid': {'file_10016',
#               'file_10025',
#               'file_10052',
#               'file_10073',
#               'file_10084',
#               'file_10109',
#               'file_10180',
#               'file_10195',
#               'file_10206',
#               'file_10215',
#               'file_10239',
#               'file_10248',
#               'file_10274',
#               'file_10286',
#               'file_10308',
#               'file_10335',
#               'file_10363',
#               'file_10393',
#               'file_10395',
#               'file_10401',
#               'file_10446',
#               'file_10478',
#               'file_10486',
#               'file_10524',
#               'file_10608',
#               'file_10619',
#               'file_10626',
#               'file_10643',
#               'file_10650',
#               'file_10660',
#               'file_10672',
#               'file_10724',
#               'file_10728',
#               'file_10757',
#               'file_10794',
#               'file_10849',
#               'file_10861',
#               'file_10901',
#               'file_10981',
#               'file_11020',
#               'file_11039',
#               'file_11105',
#               'file_11278',
#               'file_11310',
#               'file_11313',
#               'file_11342',
#               'file_11349',
#               'file_11353',
#               'file_11361',
#               'file_11365',
#               'file_11375',
#               'file_11394'},
#              'parallel': {'file_10215',
#               'file_10250',
#               'file_10309',
#               'file_10384',
#               'file_10387',
#               'file_10752',
#               'file_10792',
#               'file_11076',
#               'file_11145',
#               'file_11168',
#               'file_11189',
#               'file_11307',
#               'file_11308',
#               'file_11323',
#               'file_11381'},
#              'figur': {'file_10065',
#               'file_10066',
#               'file_10137',
#               'file_10162',
#               'file_10213',
#               'file_10215',
#               'file_10343',
#               'file_10375',
#               'file_10376',
#               'file_10508',
#               'file_10512',
#               'file_10762',
#               'file_10768',
#               'file_10830',
#               'file_11203',
#               'file_11329',
#               'file_11333'},
#              'lossi': {'file_10215', 'file_10804', 'file_11311'},
#              'resist': {'file_10035',
#               'file_10065',
#               'file_10168',
#               'file_10177',
#               'file_10180',
#               'file_10213',
#               'file_10215',
#               'file_10223',
#               'file_10331',
#               'file_10370',
#               'file_10411',
#               'file_10617',
#               'file_10620',
#               'file_10643',
#               'file_10769',
#               'file_10776',
#               'file_10780',
#               'file_10813',
#               'file_10885',
#               'file_10902',
#               'file_10907',
#               'file_11183',
#               'file_11208',
#               'file_11289',
#               'file_11304',
#               'file_11305',
#               'file_11310'},
#              'concentr': {'file_10016',
#               'file_10068',
#               'file_10299',
#               'file_10440',
#               'file_10842',
#               'file_10860',
#               'file_10861',
#               'file_11349',
#               'file_11367'},
#              'ion': {'file_10226',
#               'file_10227',
#               'file_10289',
#               'file_10290',
#               'file_10299',
#               'file_10387',
#               'file_10389',
#               'file_10440',
#               'file_10522',
#               'file_10665',
#               'file_10713',
#               'file_10790',
#               'file_10794',
#               'file_10852',
#               'file_10857',
#               'file_10858',
#               'file_10861',
#               'file_10993',
#               'file_11081',
#               'file_11088',
#               'file_11103',
#               'file_11162',
#               'file_11213',
#               'file_11260',
#               'file_11274',
#               'file_11275',
#               'file_11344',
#               'file_11352',
#               'file_11357',
#               'file_11398',
#               'file_11415'},
#              'probe': {'file_10237',
#               'file_10588',
#               'file_10836',
#               'file_10861',
#               'file_11078',
#               'file_11141',
#               'file_11260',
#               'file_11349',
#               'file_11415'},
#              'spectrum': {'file_10146',
#               'file_10188',
#               'file_10248',
#               'file_10267',
#               'file_10270',
#               'file_10271',
#               'file_10290',
#               'file_10291',
#               'file_10345',
#               'file_10391',
#               'file_10393',
#               'file_10418',
#               'file_10537',
#               'file_10545',
#               'file_10552',
#               'file_10566',
#               'file_10622',
#               'file_10630',
#               'file_10725',
#               'file_10727',
#               'file_10792',
#               'file_10861',
#               'file_10981',
#               'file_11213',
#               'file_11238',
#               'file_11240',
#               'file_11243',
#               'file_11249',
#               'file_11376',
#               'file_11411'},
#              'mass': {'file_10223',
#               'file_10273',
#               'file_10275',
#               'file_10858',
#               'file_10861',
#               'file_11106'},
#              'electron': {'file_10013',
#               'file_10014',
#               'file_10018',
#               'file_10026',
#               'file_10061',
#               'file_10074',
#               'file_10075',
#               'file_10087',
#               'file_10089',
#               'file_10090',
#               'file_10109',
#               'file_10126',
#               'file_10153',
#               'file_10221',
#               'file_10223',
#               'file_10224',
#               'file_10226',
#               'file_10227',
#               'file_10234',
#               'file_10267',
#               'file_10274',
#               'file_10275',
#               'file_10287',
#               'file_10290',
#               'file_10291',
#               'file_10298',
#               'file_10309',
#               'file_10381',
#               'file_10383',
#               'file_10386',
#               'file_10387',
#               'file_10388',
#               'file_10389',
#               'file_10391',
#               'file_10392',
#               'file_10393',
#               'file_10395',
#               'file_10396',
#               'file_10418',
#               'file_10445',
#               'file_10451',
#               'file_10486',
#               'file_10499',
#               'file_10521',
#               'file_10522',
#               'file_10533',
#               'file_10545',
#               'file_10546',
#               'file_10570',
#               'file_10588',
#               'file_10592',
#               'file_10593',
#               'file_10600',
#               'file_10647',
#               'file_10648',
#               'file_10652',
#               'file_10663',
#               'file_10664',
#               'file_10665',
#               'file_10680',
#               'file_10704',
#               'file_10705',
#               'file_10713',
#               'file_10716',
#               'file_10718',
#               'file_10758',
#               'file_10777',
#               'file_10782',
#               'file_10784',
#               'file_10787',
#               'file_10790',
#               'file_10792',
#               'file_10795',
#               'file_10796',
#               'file_10834',
#               'file_10850',
#               'file_10851',
#               'file_10852',
#               'file_10857',
#               'file_10858',
#               'file_10860',
#               'file_10861',
#               'file_10862',
#               'file_10907',
#               'file_10911',
#               'file_10912',
#               'file_10917',
#               'file_10927',
#               'file_10928',
#               'file_10932',
#               'file_10946',
#               'file_10950',
#               'file_10970',
#               'file_10984',
#               'file_10993',
#               'file_10997',
#               'file_11004',
#               'file_11026',
#               'file_11078',
#               'file_11080',
#               'file_11081',
#               'file_11083',
#               'file_11090',
#               'file_11097',
#               'file_11107',
#               'file_11108',
#               'file_11141',
#               'file_11144',
#               'file_11153',
#               'file_11168',
#               'file_11201',
#               'file_11208',
#               'file_11213',
#               'file_11215',
#               'file_11242',
#               'file_11243',
#               'file_11244',
#               'file_11251',
#               'file_11259',
#               'file_11260',
#               'file_11261',
#               'file_11262',
#               'file_11263',
#               'file_11265',
#               'file_11267',
#               'file_11269',
#               'file_11270',
#               'file_11274',
#               'file_11276',
#               'file_11289',
#               'file_11342',
#               'file_11345',
#               'file_11349',
#               'file_11352',
#               'file_11353',
#               'file_11394',
#               'file_11405',
#               'file_11408',
#               'file_11416',
#               'file_11422'},
#              'satellit': {'file_10109',
#               'file_10110',
#               'file_10113',
#               'file_10281',
#               'file_10282',
#               'file_10283',
#               'file_10284',
#               'file_10286',
#               'file_10287',
#               'file_10288',
#               'file_10294',
#               'file_10375',
#               'file_10411',
#               'file_10427',
#               'file_10429',
#               'file_10431',
#               'file_10433',
#               'file_10435',
#               'file_10436',
#               'file_10450',
#               'file_10462',
#               'file_10511',
#               'file_10561',
#               'file_10564',
#               'file_10565',
#               'file_10566',
#               'file_10567',
#               'file_10672',
#               'file_10695',
#               'file_10696',
#               'file_10697',
#               'file_10698',
#               'file_10701',
#               'file_10713',
#               'file_10718',
#               'file_10719',
#               'file_10720',
#               'file_10841',
#               'file_10842',
#               'file_10845',
#               'file_10847',
#               'file_10861',
#               'file_10862',
#               'file_10879',
#               'file_10970',
#               'file_10985',
#               'file_10986',
#               'file_10988',
#               'file_11133',
#               'file_11134',
#               'file_11136',
#               'file_11138',
#               'file_11141',
#               'file_11244',
#               'file_11254',
#               'file_11255',
#               'file_11259',
#               'file_11270',
#               'file_11373',
#               'file_11397',
#               'file_11398',
#               'file_11400',
#               'file_11416'},
#              'use': {'file_10011',
#               'file_10014',
#               'file_10025',
#               'file_10031',
#               'file_10043',
#               'file_10044',
#               'file_10046',
#               'file_10056',
#               'file_10059',
#               'file_10075',
#               'file_10076',
#               'file_10077',
#               'file_10085',
#               'file_10102',
#               'file_10117',
#               'file_10127',
#               'file_10133',
#               'file_10135',
#               'file_10143',
#               'file_10154',
#               'file_10157',
#               'file_10162',
#               'file_10173',
#               'file_10182',
#               'file_10183',
#               'file_10213',
#               'file_10214',
#               'file_10216',
#               'file_10218',
#               'file_10228',
#               'file_10235',
#               'file_10237',
#               'file_10259',
#               'file_10271',
#               'file_10281',
#               'file_10291',
#               'file_10320',
#               'file_10326',
#               'file_10335',
#               'file_10336',
#               'file_10339',
#               'file_10340',
#               'file_10350',
#               'file_10355',
#               'file_10373',
#               'file_10378',
#               'file_10388',
#               'file_10390',
#               'file_10407',
#               'file_10410',
#               'file_10457',
#               'file_10465',
#               'file_10466',
#               'file_10470',
#               'file_10476',
#               'file_10480',
#               'file_10481',
#               'file_10485',
#               'file_10486',
#               'file_10494',
#               'file_10506',
#               'file_10508',
#               'file_10509',
#               'file_10510',
#               'file_10514',
#               'file_10516',
#               'file_10521',
#               'file_10528',
#               'file_10545',
#               'file_10551',
#               'file_10552',
#               'file_10564',
#               'file_10566',
#               'file_10571',
#               'file_10576',
#               'file_10579',
#               'file_10588',
#               'file_10593',
#               'file_10614',
#               'file_10615',
#               'file_10616',
#               'file_10626',
#               'file_10640',
#               'file_10652',
#               'file_10655',
#               'file_10671',
#               'file_10672',
#               'file_10719',
#               'file_10737',
#               'file_10738',
#               'file_10744',
#               'file_10749',
#               'file_10755',
#               'file_10756',
#               'file_10760',
#               'file_10762',
#               'file_10772',
#               'file_10774',
#               'file_10779',
#               'file_10788',
#               'file_10793',
#               'file_10800',
#               'file_10804',
#               'file_10809',
#               'file_10812',
#               'file_10814',
#               'file_10836',
#               'file_10861',
#               'file_10873',
#               'file_10875',
#               'file_10876',
#               'file_10885',
#               'file_10891',
#               'file_10937',
#               'file_10939',
#               'file_10940',
#               'file_10942',
#               'file_10944',
#               'file_11015',
#               'file_11020',
#               'file_11022',
#               'file_11023',
#               'file_11024',
#               'file_11033',
#               'file_11035',
#               'file_11043',
#               'file_11044',
#               'file_11049',
#               'file_11054',
#               'file_11055',
#               'file_11059',
#               'file_11060',
#               'file_11063',
#               'file_11078',
#               'file_11090',
#               'file_11097',
#               'file_11103',
#               'file_11104',
#               'file_11122',
#               'file_11126',
#               'file_11127',
#               'file_11138',
#               'file_11143',
#               'file_11145',
#               'file_11164',
#               'file_11169',
#               'file_11180',
#               'file_11189',
#               'file_11211',
#               'file_11225',
#               'file_11231',
#               'file_11235',
#               'file_11240',
#               'file_11241',
#               'file_11243',
#               'file_11251',
#               'file_11259',
#               'file_11263',
#               'file_11270',
#               'file_11276',
#               'file_11279',
#               'file_11291',
#               'file_11296',
#               'file_11301',
#               'file_11315',
#               'file_11333',
#               'file_11343',
#               'file_11365',
#               'file_11366',
#               'file_11367',
#               'file_11375',
#               'file_11377',
#               'file_11382',
#               'file_11394',
#               'file_11423',
#               'file_11428'},
#              'electrod': {'file_10061',
#               'file_10070',
#               'file_10622',
#               'file_10861',
#               'file_10910'},
#              'born': {'file_10287',
#               'file_10401',
#               'file_10552',
#               'file_10565',
#               'file_10604',
#               'file_10861',
#               'file_11238'},
#              'temperatur': {'file_10016',
#               'file_10053',
#               'file_10065',
#               'file_10077',
#               'file_10094',
#               'file_10200',
#               'file_10203',
#               'file_10205',
#               'file_10235',
#               'file_10248',
#               'file_10291',
#               'file_10298',
#               'file_10364',
#               'file_10369',
#               'file_10452',
#               'file_10498',
#               'file_10598',
#               'file_10790',
#               'file_10814',
#               'file_10861',
#               'file_10884',
#               'file_10919',
#               'file_11004',
#               'file_11068',
#               'file_11091',
#               'file_11103',
#               'file_11141',
#               'file_11162',
#               'file_11164',
#               'file_11195',
#               'file_11211',
#               'file_11260',
#               'file_11269',
#               'file_11318',
#               'file_11342',
#               'file_11349',
#               'file_11361',
#               'file_11397',
#               'file_11405'},
#              'langmuir': {'file_10861',
#               'file_11078',
#               'file_11141',
#               'file_11349',
#               'file_11415'},
#              'ionospher': {'file_10010',
#               'file_10011',
#               'file_10013',
#               'file_10014',
#               'file_10018',
#               'file_10019',
#               'file_10094',
#               'file_10116',
#               'file_10119',
#               'file_10122',
#               'file_10123',
#               'file_10124',
#               'file_10125',
#               'file_10126',
#               'file_10128',
#               'file_10130',
#               'file_10132',
#               'file_10135',
#               'file_10136',
#               'file_10137',
#               'file_10139',
#               'file_10146',
#               'file_10279',
#               'file_10281',
#               'file_10287',
#               'file_10288',
#               'file_10289',
#               'file_10290',
#               'file_10291',
#               'file_10294',
#               'file_10295',
#               'file_10297',
#               'file_10301',
#               'file_10302',
#               'file_10411',
#               'file_10412',
#               'file_10423',
#               'file_10430',
#               'file_10435',
#               'file_10439',
#               'file_10442',
#               'file_10443',
#               'file_10445',
#               'file_10447',
#               'file_10453',
#               'file_10569',
#               'file_10570',
#               'file_10571',
#               'file_10572',
#               'file_10574',
#               'file_10575',
#               'file_10576',
#               'file_10578',
#               'file_10579',
#               'file_10580',
#               'file_10586',
#               'file_10590',
#               'file_10591',
#               'file_10592',
#               'file_10704',
#               'file_10705',
#               'file_10707',
#               'file_10708',
#               'file_10713',
#               'file_10717',
#               'file_10719',
#               'file_10727',
#               'file_10728',
#               'file_10830',
#               'file_10832',
#               'file_10847',
#               'file_10849',
#               'file_10850',
#               'file_10851',
#               'file_10852',
#               'file_10853',
#               'file_10854',
#               'file_10856',
#               'file_10859',
#               'file_10860',
#               'file_10861',
#               'file_10862',
#               'file_10863',
#               'file_10864',
#               'file_10865',
#               'file_10868',
#               'file_10928',
#               'file_10993',
#               'file_10994',
#               'file_10995',
#               'file_10996',
#               'file_11000',
#               'file_11001',
#               'file_11004',
#               'file_11005',
#               'file_11019',
#               'file_11130',
#               'file_11134',
#               'file_11143',
#               'file_11146',
#               'file_11151',
#               'file_11152',
#               'file_11160',
#               'file_11260',
#               'file_11261',
#               'file_11262',
#               'file_11265',
#               'file_11267',
#               'file_11269',
#               'file_11270',
#               'file_11273',
#               'file_11275',
#               'file_11280',
#               'file_11299',
#               'file_11394',
#               'file_11400',
#               'file_11403',
#               'file_11404',
#               'file_11405',
#               'file_11406',
#               'file_11407',
#               'file_11408',
#               'file_11410',
#               'file_11411',
#               'file_11413',
#               'file_11415',
#               'file_11419',
#               'file_11420',
#               'file_11422'},
#              'studi': {'file_10019',
#               'file_10074',
#               'file_10092',
#               'file_10116',
#               'file_10128',
#               'file_10151',
#               'file_10239',
#               'file_10246',
#               'file_10282',
#               'file_10297',
#               'file_10311',
#               'file_10312',
#               'file_10330',
#               'file_10408',
#               'file_10410',
#               'file_10422',
#               'file_10464',
#               'file_10595',
#               'file_10613',
#               'file_10660',
#               'file_10707',
#               'file_10709',
#               'file_10728',
#               'file_10788',
#               'file_10818',
#               'file_10819',
#               'file_10853',
#               'file_10861',
#               'file_10874',
#               'file_10959',
#               'file_10983',
#               'file_10986',
#               'file_10990',
#               'file_10996',
#               'file_11039',
#               'file_11057',
#               'file_11151',
#               'file_11153',
#               'file_11160',
#               'file_11247',
#               'file_11251',
#               'file_11278',
#               'file_11308',
#               'file_11342',
#               'file_11351',
#               'file_11359',
#               'file_11382',
#               'file_11389',
#               'file_11391',
#               'file_11394',
#               'file_11410',
#               'file_11412',
#               'file_11420'},
#              'frequent': {'file_10539', 'file_10982'},
#              'wave': {'file_10066',
#               'file_10075',
#               'file_10090',
#               'file_10122',
#               'file_10123',
#               'file_10126',
#               'file_10151',
#               'file_10201',
#               'file_10207',
#               'file_10210',
#               'file_10226',
#               'file_10228',
#               'file_10229',
#               'file_10234',
#               'file_10235',
#               'file_10238',
#               'file_10240',
#               'file_10242',
#               'file_10243',
#               'file_10244',
#               'file_10250',
#               'file_10260',
#               'file_10268',
#               'file_10280',
#               'file_10369',
#               'file_10373',
#               'file_10386',
#               'file_10387',
#               'file_10388',
#               'file_10389',
#               'file_10390',
#               'file_10395',
#               'file_10396',
#               'file_10397',
#               'file_10398',
#               'file_10399',
#               'file_10400',
#               'file_10412',
#               'file_10455',
#               'file_10482',
#               'file_10502',
#               'file_10508',
#               'file_10511',
#               'file_10519',
#               'file_10524',
#               'file_10525',
#               'file_10630',
#               'file_10640',
#               'file_10650',
#               'file_10655',
#               'file_10658',
#               'file_10659',
#               'file_10660',
#               'file_10704',
#               'file_10753',
#               'file_10779',
#               'file_10783',
#               'file_10788',
#               'file_10791',
#               'file_10792',
#               'file_10794',
#               'file_10800',
#               'file_10804',
#               'file_10807',
#               'file_10835',
#               'file_10849',
#               'file_10860',
#               'file_10864',
#               'file_10868',
#               'file_10897',
#               'file_10912',
#               'file_10923',
#               'file_10926',
#               'file_10927',
#               'file_10928',
#               'file_10931',
#               'file_10973',
#               'file_10980',
#               'file_10981',
#               'file_10982',
#               'file_11001',
#               'file_11005',
#               'file_11061',
#               'file_11063',
#               'file_11072',
#               'file_11083',
#               'file_11085',
#               'file_11099',
#               'file_11130',
#               'file_11143',
#               'file_11189',
#               'file_11215',
#               'file_11217',
#               'file_11220',
#               'file_11231',
#               'file_11262',
#               'file_11265',
#               'file_11323',
#               'file_11347',
#               'file_11357',
#               'file_11381',
#               'file_11403',
#               'file_11420'},
#              'indic': {'file_10009',
#               'file_10012',
#               'file_10123',
#               'file_10162',
#               'file_10299',
#               'file_10528',
#               'file_10558',
#               'file_10579',
#               'file_10701',
#               'file_10738',
#               'file_10830',
#               'file_10856',
#               'file_10958',
#               'file_10982',
#               'file_10988',
#               'file_11049',
#               'file_11050',
#               'file_11057',
#               'file_11066',
#               'file_11160',
#               'file_11203',
#               'file_11244',
#               'file_11280',
#               'file_11394'},
#              'period': {'file_10010',
#               'file_10012',
#               'file_10090',
#               'file_10283',
#               'file_10284',
#               'file_10313',
#               'file_10412',
#               'file_10422',
#               'file_10426',
#               'file_10427',
#               'file_10431',
#               'file_10507',
#               'file_10570',
#               'file_10591',
#               'file_10599',
#               'file_10602',
#               'file_10680',
#               'file_10688',
#               'file_10696',
#               'file_10709',
#               'file_10857',
#               'file_10942',
#               'file_10966',
#               'file_10982',
#               'file_10985',
#               'file_11012',
#               'file_11153',
#               'file_11235',
#               'file_11236',
#               'file_11237',
#               'file_11249',
#               'file_11255',
#               'file_11281',
#               'file_11349',
#               'file_11373',
#               'file_11393',
#               'file_11394'},
#              'geomagnet': {'file_10106',
#               'file_10107',
#               'file_10279',
#               'file_10280',
#               'file_10312',
#               'file_10313',
#               'file_10418',
#               'file_10422',
#               'file_10447',
#               'file_10545',
#               'file_10554',
#               'file_10555',
#               'file_10558',
#               'file_10574',
#               'file_10590',
#               'file_10601',
#               'file_10680',
#               'file_10690',
#               'file_10691',
#               'file_10692',
#               'file_10711',
#               'file_10828',
#               'file_10835',
#               'file_10836',
#               'file_10838',
#               'file_10859',
#               'file_10979',
#               'file_10980',
#               'file_10982',
#               'file_10983',
#               'file_10994',
#               'file_11002',
#               'file_11005',
#               'file_11009',
#               'file_11018',
#               'file_11120',
#               'file_11127',
#               'file_11130',
#               'file_11145',
#               'file_11146',
#               'file_11249',
#               'file_11268',
#               'file_11278',
#               'file_11282',
#               'file_11381',
#               'file_11389',
#               'file_11390',
#               'file_11391',
#               'file_11392',
#               'file_11393',
#               'file_11394',
#               'file_11395',
#               'file_11400',
#               'file_11413'},
#              'interv': {'file_10688', 'file_10982', 'file_11224'},
#              'travel': {'file_10066',
#               'file_10201',
#               'file_10207',
#               'file_10295',
#               'file_10369',
#               'file_10373',
#               'file_10455',
#               'file_10482',
#               'file_10508',
#               'file_10511',
#               'file_10717',
#               'file_10849',
#               'file_10862',
#               'file_10865',
#               'file_10897',
#               'file_10982',
#               'file_11001',
#               'file_11089',
#               'file_11144',
#               'file_11217',
#               'file_11381',
#               'file_11407'},
#              'associ': {'file_10046',
#               'file_10123',
#               'file_10157',
#               'file_10295',
#               'file_10349',
#               'file_10463',
#               'file_10528',
#               'file_10554',
#               'file_10688',
#               'file_10713',
#               'file_10853',
#               'file_10982',
#               'file_10988',
#               'file_11002',
#               'file_11011',
#               'file_11049',
#               'file_11076',
#               'file_11132',
#               'file_11274',
#               'file_11342',
#               'file_11366',
#               'file_11409',
#               'file_11413'},
#              'washington': {'file_10982', 'file_11216'},
#              'record': {'file_10013',
#               'file_10014',
#               'file_10125',
#               'file_10133',
#               'file_10135',
#               'file_10143',
#               'file_10196',
#               'file_10287',
#               'file_10295',
#               'file_10301',
#               'file_10422',
#               'file_10444',
#               'file_10459',
#               'file_10571',
#               'file_10728',
#               'file_10863',
#               'file_10982',
#               'file_11001',
#               'file_11143',
#               'file_11152',
#               'file_11165',
#               'file_11235',
#               'file_11237',
#               'file_11244',
#               'file_11261',
#               'file_11278',
#               'file_11284',
#               'file_11287',
#               'file_11424'},
#              'activ': {'file_10042',
#               'file_10043',
# ...
#              'potenti': {'file_10016',
#               'file_10110',
#               'file_10326',
#               'file_10647',
#               'file_10869',
#               'file_11081',
#               'file_11088',
#               'file_11134',
#               'file_11349'},
#              'tube': {'file_10070',
#               'file_10160',
#               'file_10228',
#               'file_10630',
#               'file_10647',
#               'file_10766',
#               'file_10786',
#               'file_10793',
#               'file_11369'},
#              'tool': {'file_10647'},
#              'appropri': {'file_10647'},
#              'trigonometri': {'file_10647'},
#              'axial': {'file_10122',
#               'file_10394',
#               'file_10406',
#               'file_10533',
#               'file_10647',
#               'file_11083'},
#              'trajectori': {'file_10533', 'file_10647', 'file_11120'},
#              'triangl': {'file_10647'},
#              'len': {'file_10647'},
#              'parabol': {'file_10259', 'file_10647'},
#              'flight': {'file_10014',
#               'file_10267',
#               'file_10282',
#               'file_10299',
#               'file_10427',
#               'file_10452',
#               'file_10545',
#               'file_10647',
#               'file_11160',
#               'file_11242',
#               'file_11260'},
#              'trace': {'file_10262', 'file_10647', 'file_10854', 'file_10995'},
#              'rule': {'file_10037', 'file_10647', 'file_11027'},
#              'substitut': {'file_10647', 'file_10750'},
#              'segment': {'file_10647'},
#              'memori': {'file_10157',
#               'file_10474',
#               'file_10615',
#               'file_10737',
#               'file_10873',
#               'file_10876',
#               'file_11043',
#               'file_11170',
#               'file_11293'},
#              'though': {'file_10850', 'file_11293'},
#              'protect': {'file_10567', 'file_11293'},
#              'fault': {'file_11293'},
#              'solid': {'file_10066',
#               'file_10247',
#               'file_10320',
#               'file_10334',
#               'file_10527',
#               'file_10528',
#               'file_10531',
#               'file_10618',
#               'file_10640',
#               'file_10949',
#               'file_11026',
#               'file_11055',
#               'file_11072',
#               'file_11179',
#               'file_11301',
#               'file_11370'},
#              'empti': {'file_10949', 'file_11351'},
#              'lattic': {'file_10490',
#               'file_10919',
#               'file_10949',
#               'file_11091'},
#              'canada': {'file_10576', 'file_10826', 'file_10853'},
#              'balloon': {'file_10604',
#               'file_10826',
#               'file_11248',
#               'file_11280'},
#              'churchil': {'file_10822', 'file_10826'},
#              'ellips': {'file_10122', 'file_11143'},
#              'greatest': {'file_10021',
#               'file_10122',
#               'file_10574',
#               'file_10579'},
#              'factor': {'file_10009',
#               'file_10043',
#               'file_10122',
#               'file_10188',
#               'file_10203',
#               'file_10337',
#               'file_10440',
#               'file_10778',
#               'file_10782',
#               'file_10850',
#               'file_10875',
#               'file_10980',
#               'file_11400',
#               'file_11424'},
#              'anisotropi': {'file_10122',
#               'file_10547',
#               'file_10824',
#               'file_10921'},
#              'proportion': {'file_10116'},
#              'departur': {'file_10116',
#               'file_10853',
#               'file_10857',
#               'file_10885'},
#              'motor': {'file_10116'},
#              'th': {'file_10116',
#               'file_10350',
#               'file_10418',
#               'file_10447',
#               'file_10985',
#               'file_11160',
#               'file_11209'},
#              'aris': {'file_10116',
#               'file_10191',
#               'file_10489',
#               'file_11005',
#               'file_11152',
#               'file_11352'},
#              'behaviour': {'file_10035',
#               'file_10116',
#               'file_10177',
#               'file_10508',
#               'file_10639',
#               'file_10760',
#               'file_10895',
#               'file_11035',
#               'file_11072',
#               'file_11081',
#               'file_11085',
#               'file_11262',
#               'file_11268'},
#              'percentag': {'file_10012', 'file_11273'},
#              'contour': {'file_11012', 'file_11273'},
#              'world': {'file_11001', 'file_11273', 'file_11389', 'file_11391'},
#              'datz': {'file_11273'},
#              'satisfi': {'file_10255', 'file_10282'},
#              'forc': {'file_10165',
#               'file_10255',
#               'file_10394',
#               'file_10546',
#               'file_10574',
#               'file_10784',
#               'file_10852'},
#              'free': {'file_10085',
#               'file_10255',
#               'file_10387',
#               'file_10391',
#               'file_10465',
#               'file_10519',
#               'file_10588',
#               'file_10950',
#               'file_11063',
#               'file_11071',
#               'file_11108',
#               'file_11213'},
#              'exercis': {'file_10255'},
#              'compu': {'file_10326'},
#              'script': {'file_10326'},
#              'cycl': {'file_10326',
#               'file_10615',
#               'file_10822',
#               'file_11028',
#               'file_11170'},
#              'er': {'file_10326'},
#              'bistabl': {'file_10326', 'file_10354', 'file_10738'},
#              'drawn': {'file_11389'},
#              'depict': {'file_11389'},
#              'servo': {'file_10604'},
#              'dynam': {'file_10056',
#               'file_10177',
#               'file_10195',
#               'file_10390',
#               'file_10604',
#               'file_10622',
#               'file_10691',
#               'file_10878',
#               'file_11216'},
#              'arc': {'file_10261',
#               'file_10305',
#               'file_10604',
#               'file_10912',
#               'file_11010',
#               'file_11367'},
#              'light': {'file_10085',
#               'file_10309',
#               'file_10400',
#               'file_10409',
#               'file_10440',
#               'file_10470',
#               'file_10604',
#               'file_10630',
#               'file_10809',
#               'file_10944',
#               'file_11069',
#               'file_11198',
#               'file_11229',
#               'file_11231',
#               'file_11232',
#               'file_11367'},
#              'tracker': {'file_10604'},
#              'star': {'file_10261',
#               'file_10297',
#               'file_10574',
#               'file_10604',
#               'file_11146',
#               'file_11373',
#               'file_11399'},
#              'within': {'file_10048',
#               'file_10158',
#               'file_10162',
#               'file_10235',
#               'file_10261',
#               'file_10290',
#               'file_10376',
#               'file_10470',
#               'file_10604',
#               'file_10631',
#               'file_10792',
#               'file_10805',
#               'file_10865',
#               'file_10883',
#               'file_11164',
#               'file_11318'},
#              'quantum': {'file_10222',
#               'file_10406',
#               'file_10408',
#               'file_10518',
#               'file_10937',
#               'file_11063',
#               'file_11071',
#               'file_11107',
#               'file_11213'},
#              'multimod': {'file_10408'},
#              'ideal': {'file_10328',
#               'file_10691',
#               'file_10734',
#               'file_11035',
#               'file_11063',
#               'file_11315',
#               'file_11342'},
#              'compris': {'file_10044',
#               'file_10165',
#               'file_10328',
#               'file_10505',
#               'file_10630',
#               'file_10758'},
#              'addit': {'file_10078',
#               'file_10180',
#               'file_10328',
#               'file_10350',
#               'file_10395',
#               'file_10851',
#               'file_11351',
#               'file_11411'},
#              'rel': {'file_10151',
#               'file_10267',
#               'file_10328',
#               'file_10549',
#               'file_10724',
#               'file_10778',
#               'file_10857',
#               'file_10986',
#               'file_11099',
#               'file_11118',
#               'file_11120',
#               'file_11244',
#               'file_11311',
#               'file_11357',
#               'file_11382',
#               'file_11415'},
#              'wind': {'file_10328',
#               'file_10708',
#               'file_10835',
#               'file_10883',
#               'file_10990',
#               'file_11108',
#               'file_11147',
#               'file_11408'},
#              'neg': {'file_10035',
#               'file_10107',
#               'file_10180',
#               'file_10193',
#               'file_10204',
#               'file_10205',
#               'file_10213',
#               'file_10223',
#               'file_10328',
#               'file_10353',
#               'file_10370',
#               'file_10376',
#               'file_10453',
#               'file_10769',
#               'file_10817',
#               'file_10859',
#               'file_10902',
#               'file_10921',
#               'file_11092',
#               'file_11099',
#               'file_11106',
#               'file_11267',
#               'file_11283',
#               'file_11329'},
#              'magnitud': {'file_10018',
#               'file_10117',
#               'file_10328',
#               'file_10691'},
#              'per': {'file_10093',
#               'file_10495',
#               'file_10508',
#               'file_11170',
#               'file_11171',
#               'file_11179'},
#              'adiabat': {'file_10508', 'file_11054'},
#              'taper': {'file_10337', 'file_10508'},
#              'materi': {'file_10026',
#               'file_10165',
#               'file_10237',
#               'file_10369',
#               'file_10478',
#               'file_10508',
#               'file_10528',
#               'file_10619',
#               'file_10658',
#               'file_11105',
#               'file_11220'},
#              'sh': {'file_10508'},
#              'quot': {'file_10508', 'file_10709', 'file_11262'},
#              'rutil': {'file_10508', 'file_11055'},
#              'dope': {'file_10508', 'file_11055'},
#              'focus': {'file_10508', 'file_11120', 'file_11232'},
#              'without': {'file_10106',
#               'file_10508',
#               'file_10524',
#               'file_10636',
#               'file_10650',
#               'file_10779',
#               'file_11044',
#               'file_11187',
#               'file_11315'},
#              'extern': {'file_10142',
#               'file_10201',
#               'file_10234',
#               'file_10290',
#               'file_10387',
#               'file_10391',
#               'file_10508',
#               'file_10650',
#               'file_10758',
#               'file_10784',
#               'file_10794',
#               'file_10805',
#               'file_10913',
#               'file_10928',
#               'file_11049',
#               'file_11188',
#               'file_11369',
#               'file_11403'},
#              'tunabl': {'file_10340',
#               'file_10407',
#               'file_10508',
#               'file_10512',
#               'file_10777'},
#              'nonadiabat': {'file_10508'},
#              'bandwidth': {'file_10066',
#               'file_10201',
#               'file_10205',
#               'file_10369',
#               'file_10370',
#               'file_10375',
#               'file_10376',
#               'file_10490',
#               'file_10508',
#               'file_10512',
#               'file_10623',
#               'file_10774',
#               'file_10804',
#               'file_11054',
#               'file_11066',
#               'file_11179',
#               'file_11329',
#               'file_11333'},
#              'appreci': {'file_10508', 'file_10567'},
#              'size': {'file_10508', 'file_10854', 'file_10959'},
#              'chromium': {'file_10508'},
#              'declin': {'file_10286', 'file_10415', 'file_10460'},
#              'sunspot': {'file_10012',
#               'file_10286',
#               'file_10412',
#               'file_10553',
#               'file_10856',
#               'file_10857',
#               'file_10980',
#               'file_11000',
#               'file_11283',
#               'file_11412'},
#              'allen': {'file_10107',
#               'file_10113',
#               'file_10268',
#               'file_10417',
#               'file_10462',
#               'file_10544',
#               'file_10567',
#               'file_10713',
#               'file_10842',
#               'file_10856',
#               'file_11118',
#               'file_11243'},
#              'commun': {'file_10059',
#               'file_10462',
#               'file_10511',
#               'file_10563',
#               'file_10842',
#               'file_10938',
#               'file_11335'},
#              'belt': {'file_10107',
#               'file_10113',
#               'file_10268',
#               'file_10417',
#               'file_10462',
#               'file_10544',
#               'file_10546',
#               'file_10554',
#               'file_10567',
#               'file_10678',
#               'file_10713',
#               'file_10832',
#               'file_10842',
#               'file_10856',
#               'file_10970',
#               'file_10983',
#               'file_11118',
#               'file_11131',
#               'file_11242',
#               'file_11243',
#               'file_11381'},
#              'life': {'file_10567', 'file_10842', 'file_11028'},
#              'van': {'file_10107',
#               'file_10113',
#               'file_10268',
#               'file_10417',
#               'file_10462',
#               'file_10544',
#               'file_10567',
#               'file_10713',
#               'file_10842',
#               'file_10856',
#               'file_11118',
#               'file_11243'},
#              'rico': {'file_10574', 'file_11408'},
#              'puerto': {'file_10574', 'file_11408'},
#              'sunris': {'file_10412',
#               'file_10574',
#               'file_10997',
#               'file_11153',
#               'file_11262',
#               'file_11263',
#               'file_11284',
#               'file_11405',
#               'file_11408'},
#              'hour': {'file_10447',
#               'file_10574',
#               'file_10704',
#               'file_10822',
#               'file_10865',
#               'file_11138',
#               'file_11255'},
#              'elong': {'file_10309', 'file_10569', 'file_10574', 'file_11146'},
#              'scintil': {'file_10263',
#               'file_10297',
#               'file_10430',
#               'file_10435',
#               'file_10574',
#               'file_10817',
#               'file_11146',
#               'file_11243',
#               'file_11373'},
#              'rather': {'file_10139',
#               'file_10142',
#               'file_10157',
#               'file_10574',
#               'file_10835'},
#              'scout': {'file_10566', 'file_10845'},
#              'plot': {'file_10288',
#               'file_10315',
#               'file_10575',
#               'file_10701',
#               'file_10724',
#               'file_10845',
#               'file_10857',
#               'file_10920'},
#              'follow': {'file_10297',
#               'file_10352',
#               'file_10369',
#               'file_10422',
#               'file_10590',
#               'file_10713',
#               'file_10822',
#               'file_10858',
#               'file_11092',
#               'file_11378'},
#              ...})

# %% [markdown]
# # **modelling**

# %% [markdown]
# get inverse document frequency
# *   idf = log(total docs/total docs containing term)

# %%
def get_idf(word):
  return math.log(data.shape[0] / (len(word_dict[word])))

# %% [markdown]
# get rsv ranking weights
#
#
# 1.   generate rsv of each word based on the whole training documents
# 2.   generate rsv of doc based on specific doc provided

# %%
def get_relevant_docs(docs):
  
  files = []
  for file_name in list(docs):
    if int(data[data['file_name'] == file_name]["labels"]) == 1:
      files.append( file_name )
  return files


def generate_rsv_weights():
  weights = {}
  for word in wordlist:
    terms_in_relevant_docs = len(get_relevant_docs(word_dict[word]))
    prob_of_word = terms_in_relevant_docs/(data.shape[0]+0.5)
    _log = math.log(prob_of_word/(1-prob_of_word)) if prob_of_word > 0 else 0
    weights[word] = get_idf(word) + _log
  return weights

weights = generate_rsv_weights()

# %%
weights
# Out:
# {'transient': 4.8283137373023015,
#  'elast': 6.907755278982137,
#  'mz': 6.907755278982137,
#  'planar': 6.214608098422191,
#  'uncoupl': 6.907755278982137,
#  'thermospher': 6.907755278982137,
#  'al': 5.809142990314028,
#  'calcul': -4.093844437180419,
#  'tie': 6.907755278982137,
#  'suffici': 4.605170185988092,
#  'procedur': 4.268697949366879,
#  'archipelago': 6.907755278982137,
#  'dsb': 6.907755278982137,
#  'immedi': 6.907755278982137,
#  'unfocus': 6.907755278982137,
#  'concentr': 4.710530701645918,
#  'maxwel': 6.907755278982137,
#  'beta': 6.907755278982137,
#  'subtract': 6.214608098422191,
#  'labori': 6.907755278982137,
#  'power': 3.101092789211817,
#  'integ': 6.907755278982137,
#  'juli': 5.298317366548036,
#  'prebunch': 6.907755278982137,
#  'address': 5.809142990314028,
#  'zone': 4.710530701645918,
#  'discret': 6.214608098422191,
#  'upon': 6.907755278982137,
#  'tl': 6.907755278982137,
#  'circumst': 6.907755278982137,
#  'lf': 6.907755278982137,
#  'piec': 6.907755278982137,
#  'unidirect': 6.907755278982137,
#  'portion': 6.907755278982137,
#  'mention': 6.214608098422191,
#  'group': 4.710530701645918,
#  'multipli': 5.521460917862246,
#  'review': 3.473768074496991,
#  'express': 3.6888794541139363,
#  'tempor': 6.907755278982137,
#  'magnon': 6.907755278982137,
#  'around': 5.521460917862246,
#  'withou': 6.907755278982137,
#  'form': 3.4420193761824107,
#  'design': 2.7806208939370456,
#  'receiv': 4.268697949366879,
#  'driven': 5.521460917862246,
#  'conjunct': 5.809142990314028,
#  'batteri': 6.907755278982137,
#  'striplin': 6.907755278982137,
#  'deriv': 2.9759296462578115,
#  'commut': 6.214608098422191,
#  'inter': 6.907755278982137,
#  'adjoin': 6.907755278982137,
#  'take': 4.710530701645918,
#  'infin': 6.907755278982137,
#  'cathod': -2.0789414166381537,
#  'binari': 4.509860006183766,
#  'whisper': 6.907755278982137,
#  'ultrason': 6.214608098422191,
#  'abl': 6.907755278982137,
#  'english': 5.521460917862246,
#  'durat': 4.509860006183766,
#  'magnetostrict': 6.907755278982137,
#  'similar': 4.199705077879927,
#  'possibl': 3.2968373663379125,
#  'text': 6.907755278982137,
#  'follow': 4.605170185988092,
#  'demonstr': 5.115995809754082,
#  'amplifi': 2.501036031717884,
#  'seriou': 6.907755278982137,
#  'discover': 6.214608098422191,
#  'spheric': 4.8283137373023015,
#  'potenti': 4.710530701645918,
#  'sponsor': 6.907755278982137,
#  'withstand': 6.907755278982137,
#  'lesser': 6.907755278982137,
#  'cluster': 5.809142990314028,
#  'invari': 6.907755278982137,
#  'thermodynam': 6.214608098422191,
#  'manufactur': 6.214608098422191,
#  'reflect': 3.3813947543659757,
#  'incid': 4.074541934925921,
#  'maximum': 4.135166556742356,
#  'alkalin': 6.907755278982137,
#  'lead': 4.8283137373023015,
#  'magneto': 4.710530701645918,
#  'hobart': 6.214608098422191,
#  'seen': 6.907755278982137,
#  'autocorrel': 6.214608098422191,
#  'static': 4.8283137373023015,
#  'cascad': 4.710530701645918,
#  'ozon': 6.214608098422191,
#  'schmitt': 6.907755278982137,
#  'emerg': 6.214608098422191,
#  'slough': 6.907755278982137,
#  'ionogram': 4.961845129926823,
#  'terr': 6.907755278982137,
#  'due': 3.3524072174927233,
#  'filamentari': 6.907755278982137,
#  'proportion': 6.907755278982137,
#  'pictur': 6.214608098422191,
#  'shape': 4.199705077879927,
#  'failur': 6.214608098422191,
#  'residu': 6.214608098422191,
#  'seeger': 6.907755278982137,
#  'exterior': 6.907755278982137,
#  'schedul': 6.907755278982137,
#  'next': 6.907755278982137,
#  'success': 5.115995809754082,
#  'per': 5.115995809754082,
#  'phonon': 6.214608098422191,
#  'present': 3.506557897319982,
#  'decametr': 6.214608098422191,
#  'mean': 3.7722610630529876,
#  'stormi': 6.907755278982137,
#  'frequent': 6.214608098422191,
#  'height': 2.995732273553991,
#  'trigger': 5.115995809754082,
#  'gravit': 6.214608098422191,
#  'littl': 6.214608098422191,
#  'toler': 6.907755278982137,
#  'bott': 6.907755278982137,
#  'hyperfin': 6.214608098422191,
#  'ellips': 6.214608098422191,
#  'mesospher': 6.907755278982137,
#  'corpuscular': 4.961845129926823,
#  'twice': 5.521460917862246,
#  'heavi': 5.809142990314028,
#  'striat': 6.907755278982137,
#  'celoscop': 6.907755278982137,
#  'balanc': 5.809142990314028,
#  'wave': 2.2730262907525014,
#  'stray': 6.907755278982137,
#  'incoher': 6.214608098422191,
#  'technic': 6.214608098422191,
#  'indic': 3.7297014486341915,
#  'ephi': 6.907755278982137,
#  'sreen': 6.907755278982137,
#  'anc': 6.907755278982137,
#  'japan': 6.907755278982137,
#  'overtak': 6.907755278982137,
#  'em': 3.912023005428146,
#  'dealt': 6.214608098422191,
#  'occult': 6.907755278982137,
#  'visibl': 6.907755278982137,
#  'environment': 6.907755278982137,
#  'linearli': 5.521460917862246,
#  'optoelectron': 6.907755278982137,
#  'interfer': 5.809142990314028,
#  'deplet': 5.809142990314028,
#  'nerv': 6.907755278982137,
#  'origin': 4.3428059215206005,
#  'recognit': 6.214608098422191,
#  'impuls': 6.214608098422191,
#  'solid': 4.135166556742356,
#  'catalogu': 5.809142990314028,
#  'logic': 4.710530701645918,
#  'minneapoli': 6.214608098422191,
#  'dimension': 5.298317366548036,
#  'nonsymmetr': 6.907755278982137,
#  'antenna': 6.214608098422191,
#  'strike': 6.907755278982137,
#  'sputnik': 6.907755278982137,
#  'tube': 4.710530701645918,
#  'featur': 4.422848629194137,
#  'munich': 6.907755278982137,
#  'e': 3.7297014486341915,
#  'perman': 6.907755278982137,
#  'servo': 6.907755278982137,
#  'provid': 4.135166556742356,
#  'latch': 6.907755278982137,
#  'publish': 5.809142990314028,
#  'electrodynam': 6.214608098422191,
#  'excit': 4.605170185988092,
#  'shown': 4.074541934925921,
#  'end': 4.422848629194137,
#  'shower': 5.298317366548036,
#  'gyrat': 5.809142990314028,
#  'greenland': 6.907755278982137,
#  'envelop': 5.298317366548036,
#  'refract': 4.422848629194137,
#  'colleg': 6.907755278982137,
#  'tend': 6.907755278982137,
#  'thyratron': 6.907755278982137,
#  'adiabat': 6.214608098422191,
#  'condit': 3.7722610630529876,
#  'changer': 6.907755278982137,
#  'lose': 6.907755278982137,
#  'ion': -3.433487079443464,
#  'monthli': 6.214608098422191,
#  'cygnu': 6.214608098422191,
#  'econom': 6.907755278982137,
#  'dissip': 6.214608098422191,
#  'underestim': 6.907755278982137,
#  'ia': 6.907755278982137,
#  'cro': 6.907755278982137,
#  'irregular': 4.3428059215206005,
#  'liquid': 6.214608098422191,
#  'centr': 4.605170185988092,
#  'magnetostat': 5.809142990314028,
#  'gase': 5.521460917862246,
#  'sho': 6.907755278982137,
#  'tabul': 6.214608098422191,
#  'onset': 6.907755278982137,
#  'numer': 4.422848629194137,
#  'unequ': 6.214608098422191,
#  'mixer': 5.521460917862246,
#  'compu': 6.907755278982137,
#  'clearest': 6.907755278982137,
#  'ray': 3.506557897319982,
#  'peltier': 6.907755278982137,
#  'comprehens': 5.809142990314028,
#  'reject': 5.809142990314028,
#  'opposit': 6.907755278982137,
#  'ezrth': 6.907755278982137,
#  'corpuscl': 6.907755278982137,
#  'construct': 4.199705077879927,
#  'sequenc': 5.521460917862246,
#  'poona': 6.214608098422191,
#  'apoge': 6.907755278982137,
#  'wheatston': 6.214608098422191,
#  'photograph': 5.809142990314028,
#  'impur': 5.521460917862246,
#  'axi': 4.961845129926823,
#  'coupl': 3.473768074496991,
#  'replac': 5.115995809754082,
#  'compat': 6.907755278982137,
#  'ho': 6.907755278982137,
#  'orient': 5.298317366548036,
#  'alway': 5.809142990314028,
#  'algebra': 6.907755278982137,
#  'damag': 6.214608098422191,
#  'arriv': 5.809142990314028,
#  'suppli': 4.710530701645918,
#  'nonreact': 6.907755278982137,
#  'winter': 4.710530701645918,
#  'radio': 2.4534079827286295,
#  'aspect': 5.521460917862246,
#  'hopf': 6.907755278982137,
#  'diod': 2.9565115604007097,
#  'stockholm': 6.907755278982137,
#  'nigeria': 6.907755278982137,
#  'troposcatt': 6.907755278982137,
#  'profil': 4.074541934925921,
#  'card': 6.214608098422191,
#  'exactli': 6.214608098422191,
#  'three': 3.1465551632885744,
#  'spread': 4.710530701645918,
#  'fall': 5.809142990314028,
#  'predict': 4.135166556742356,
#  'meteoroid': 6.907755278982137,
#  'sector': 6.907755278982137,
#  'riomet': 5.521460917862246,
#  'relax': 4.605170185988092,
#  'bound': 5.809142990314028,
#  'valv': 5.521460917862246,
#  'mani': 4.961845129926823,
#  'sine': 6.907755278982137,
#  'md': 6.907755278982137,
#  'analyt': 5.115995809754082,
#  'tantalum': 6.907755278982137,
#  'extens': 4.422848629194137,
#  'horizont': 4.605170185988092,
#  'stimul': 4.961845129926823,
#  'quantum': 4.710530701645918,
#  'fade': 5.809142990314028,
#  'state': 3.611918412977808,
#  'surfac': 3.816712825623821,
#  'scatter': 3.7297014486341915,
#  'declin': 5.809142990314028,
#  'radar': 4.135166556742356,
#  'identifi': 5.298317366548036,
#  'telecommun': 6.907755278982137,
#  'ith': 6.907755278982137,
#  'scan': 5.809142990314028,
#  'sharpli': 6.214608098422191,
#  'bureau': 6.907755278982137,
#  'ideal': 4.961845129926823,
#  'involv': 4.422848629194137,
#  'boltzmann': 5.809142990314028,
#  'adder': 6.907755278982137,
#  'movement': 4.710530701645918,
#  'devic': 3.816712825623821,
#  'becom': 6.907755278982137,
#  'gaseou': 4.961845129926823,
#  'boxcar': 6.907755278982137,
#  'maryn': 6.907755278982137,
#  'pnpn': 6.214608098422191,
#  'radiometr': 6.907755278982137,
#  'uptap': 6.907755278982137,
#  'oxygen': 5.521460917862246,
#  'stand': 5.521460917862246,
#  'semiannu': 6.907755278982137,
#  'nonrealiz': 6.907755278982137,
#  'half': 4.8283137373023015,
#  'sodankyla': 6.907755278982137,
#  'paramet': 3.540459448995663,
#  'hot': 5.809142990314028,
#  'seven': 6.214608098422191,
#  'banalor': 6.907755278982137,
#  'panel': 6.907755278982137,
#  'imperfect': 6.907755278982137,
#  'adopt': 6.907755278982137,
#  'write': 6.214608098422191,
#  'bear': 6.214608098422191,
#  'lindau': 6.907755278982137,
#  'amount': 6.907755278982137,
#  'pure': 6.214608098422191,
#  'reproduc': 6.907755278982137,
#  'radioact': 6.214608098422191,
#  'satisfactori': 5.809142990314028,
#  'neuristor': 6.214608098422191,
#  'overcom': 6.214608098422191,
#  'implic': 6.907755278982137,
#  'exceed': 5.521460917862246,
#  'sun': 4.3428059215206005,
#  'comput': 3.411247717515657,
#  'oxid': 6.214608098422191,
#  'ultraviolet': 5.809142990314028,
#  'johnson': 6.907755278982137,
#  'nord': 6.907755278982137,
#  'especi': 6.907755278982137,
#  'equival': 4.199705077879927,
#  'ew': 6.907755278982137,
#  'uncertainti': 6.907755278982137,
#  'jacobi': 6.907755278982137,
#  'mere': 6.907755278982137,
#  'photospher': 6.907755278982137,
#  'radial': 5.115995809754082,
#  'period': 3.2968373663379125,
#  'ferrit': 4.268697949366879,
#  'lifetim': 5.809142990314028,
#  'martyn': 6.907755278982137,
#  'spacecraft': 6.907755278982137,
#  'heat': 4.268697949366879,
#  'anomali': 4.961845129926823,
#  'add': 6.907755278982137,
#  'ledg': 6.907755278982137,
#  'oblat': 6.214608098422191,
#  'given': 2.198225077669803,
#  'smooth': 5.809142990314028,
#  'tensor': 5.521460917862246,
#  'might': 6.907755278982137,
#  'recomput': 6.907755278982137,
#  'lump': 5.521460917862246,
#  'raman': 6.907755278982137,
#  'taper': 6.214608098422191,
#  'percentag': 6.214608098422191,
#  'pass': 3.9633162998156966,
#  'coverag': 6.214608098422191,
#  'radiu': 5.115995809754082,
#  'list': 6.907755278982137,
#  'interact': 3.7297014486341915,
#  'find': 5.521460917862246,
#  'goldstein': 6.907755278982137,
#  'sphere': 6.214608098422191,
#  'wideband': 6.907755278982137,
#  'synchrotron': 6.907755278982137,
#  'nonvanish': 6.907755278982137,
#  'laboratori': 5.809142990314028,
#  'former': 6.214608098422191,
#  'outer': 4.199705077879927,
#  'stage': 4.268697949366879,
#  'modif': 5.298317366548036,
#  'morn': 6.214608098422191,
#  'ordin': 6.214608098422191,
#  'relev': 6.907755278982137,
#  'philadelphia': 6.907755278982137,
#  'issu': 6.907755278982137,
#  'tail': 6.907755278982137,
#  'merit': 5.809142990314028,
#  'rumi': 6.907755278982137,
#  'geomagnet': 2.9187712324178627,
#  'u': 6.907755278982137,
#  'optim': 6.214608098422191,
#  'tool': 6.907755278982137,
#  'wide': 4.074541934925921,
#  'interband': 6.907755278982137,
#  'imag': 5.115995809754082,
#  'collid': 6.907755278982137,
#  'geometri': 5.809142990314028,
#  'astrophys': 6.214608098422191,
#  'singli': 6.907755278982137,
#  'drum': 6.907755278982137,
#  'block': 5.809142990314028,
#  'septemb': 4.961845129926823,
#  'asymmetri': 5.809142990314028,
#  'incident': 6.907755278982137,
#  'climatolog': 6.907755278982137,
#  'mode': 3.473768074496991,
#  'unexpect': 6.214608098422191,
#  'varactor': 4.961845129926823,
#  'breakdown': 5.521460917862246,
#  'fermi': 6.907755278982137,
#  'cw': 6.907755278982137,
#  'p': 6.907755278982137,
#  'improv': 4.268697949366879,
#  'analys': 3.611918412977808,
#  'second': 4.074541934925921,
#  'transmit': 4.8283137373023015,
#  'split': 5.521460917862246,
#  'dissoci': 6.907755278982137,
#  'ocean': 6.214608098422191,
#  'lunisolar': 6.214608098422191,
#  'tightli': 6.907755278982137,
#  'geophys': 6.907755278982137,
#  'electrostat': 4.8283137373023015,
#  'sputter': 6.214608098422191,
#  'continuum': 6.214608098422191,
#  'accomplish': 6.907755278982137,
#  'tamal': 6.907755278982137,
#  'fatigu': 6.214608098422191,
#  'octav': 6.907755278982137,
#  'weak': 5.298317366548036,
#  'similitud': 6.907755278982137,
#  'campbel': 6.907755278982137,
#  'outermost': 6.907755278982137,
#  'gate': 6.214608098422191,
#  'variabl': 3.7722610630529876,
#  'potentiomet': 6.907755278982137,
#  'circul': 6.214608098422191,
#  'possess': 6.907755278982137,
#  'essenti': 6.907755278982137,
#  'demodul': 5.809142990314028,
#  'window': 6.907755278982137,
#  'brigg': 6.907755278982137,
#  'nitrogen': 5.809142990314028,
#  'relationship': 6.214608098422191,
#  'transfluxor': 5.298317366548036,
#  'voltag': 3.540459448995663,
#  'begin': 6.907755278982137,
#  'entri': 6.907755278982137,
#  'underli': 6.907755278982137,
#  'increment': 6.214608098422191,
#  'simul': 5.521460917862246,
#  'corbino': 6.907755278982137,
#  'geolog': 6.907755278982137,
#  'type': 2.7333680090865,
#  'overhead': 6.907755278982137,
#  'italian': 6.907755278982137,
#  'mm': 6.907755278982137,
#  'seem': 5.809142990314028,
#  'round': 6.907755278982137,
#  'net': 6.214608098422191,
#  'kirchhoff': 6.214608098422191,
#  'releas': 6.907755278982137,
#  'shhsrropos': 6.907755278982137,
#  'pulkov': 6.214608098422191,
#  'ascrib': 5.521460917862246,
#  'kemp': 6.907755278982137,
#  'constitut': 6.907755278982137,
#  'bombard': 6.214608098422191,
#  'dip': 6.907755278982137,
#  'extraordinari': 6.907755278982137,
#  'univers': 6.214608098422191,
#  'current': -3.9507435935397455,
#  'partit': 6.907755278982137,
#  'late': 6.214608098422191,
#  'proof': 6.907755278982137,
#  'practic': 3.912023005428146,
#  'shadow': 5.809142990314028,
#  'horn': 6.214608098422191,
#  'centimetr': 6.907755278982137,
#  'helitran': 6.907755278982137,
#  'node': 6.214608098422191,
#  'ambient': 6.907755278982137,
#  'togeth': 5.521460917862246,
#  'wien': 6.907755278982137,
#  'storm': 3.411247717515657,
#  'connect': 4.509860006183766,
#  'departur': 5.521460917862246,
#  'bonn': 6.907755278982137,
#  'plane': 3.473768074496991,
#  'quadratur': 6.907755278982137,
#  'strong': 4.605170185988092,
#  'go': 6.907755278982137,
#  'emiss': -3.0895413272320487,
#  'metal': -2.6385572045735763,
#  'extragalact': 5.521460917862246,
#  'techniqu': 3.3524072174927233,
#  'certain': 4.509860006183766,
#  'reactiv': 5.298317366548036,
#  'novaya': 6.907755278982137,
#  'davi': 6.907755278982137,
#  'multist': 6.907755278982137,
#  'perfor': 6.907755278982137,
#  'simpler': 6.907755278982137,
#  'oslo': 6.907755278982137,
#  'correl': 3.8632328412587142,
#  'kaenel': 6.907755278982137,
#  'bloch': 6.907755278982137,
#  'occur': 3.473768074496991,
#  'crochet': 6.907755278982137,
#  'superior': 6.907755278982137,
#  'set': 5.298317366548036,
#  'mesa': 6.907755278982137,
#  'ba': 6.907755278982137,
#  'metr': 6.907755278982137,
#  'afbmd': 6.907755278982137,
#  'may': 3.649658740960655,
#  'accur': 4.605170185988092,
#  'yield': 5.809142990314028,
#  'cylindr': 4.509860006183766,
#  'strongli': 5.809142990314028,
#  'diagram': 5.521460917862246,
#  'splot': 6.907755278982137,
#  'reaction': 6.214608098422191,
#  'weather': 6.214608098422191,
#  'contact': 6.907755278982137,
#  'stop': 5.521460917862246,
#  'martin': 6.907755278982137,
#  'simplifi': 4.8283137373023015,
#  'get': 6.907755278982137,
#  'interpret': 4.135166556742356,
#  'interv': 5.809142990314028,
#  'scale': 4.199705077879927,
#  'prior': 6.907755278982137,
#  'alon': 6.907755278982137,
#  'gross': 5.809142990314028,
#  'shock': 5.521460917862246,
#  'inadequ': 6.907755278982137,
#  'materi': 4.509860006183766,
#  'isotop': 6.907755278982137,
#  'enhanc': 5.521460917862246,
#  'unaffect': 6.907755278982137,
#  'enumer': 6.907755278982137,
#  'descript': 3.7722610630529876,
#  'sub': 6.214608098422191,
#  'luminos': 6.907755278982137,
#  'complic': 6.907755278982137,
#  'intrins': 5.809142990314028,
#  'experiment': 3.1941832122778293,
#  'hundredth': 6.907755278982137,
#  'constant': -3.218375699826519,
#  'sheath': 6.907755278982137,
#  'futur': 5.521460917862246,
#  'synthes': 5.521460917862246,
#  'signatur': 6.907755278982137,
#  'achiev': 4.268697949366879,
#  'stablein': 6.907755278982137,
#  'ottawa': 6.907755278982137,
#  'phon': 6.907755278982137,
#  'deceler': 6.907755278982137,
#  'first': 4.3428059215206005,
#  'azimuth': 6.214608098422191,
#  'rigor': 6.214608098422191,
#  'faraday': 5.521460917862246,
#  'middl': 6.214608098422191,
#  'event': 4.605170185988092,
#  'repeat': 5.521460917862246,
#  'media': 5.521460917862246,
#  'error': 4.3428059215206005,
#  'explos': 5.521460917862246,
#  'video': 6.214608098422191,
#  'chromospher': 6.907755278982137,
#  'joint': 6.907755278982137,
#  'defin': 4.8283137373023015,
#  'work': 4.199705077879927,
#  'wate': 6.907755278982137,
#  'shell': 6.907755278982137,
#  'masur': 6.907755278982137,
#  'lock': 6.214608098422191,
#  'creation': 6.907755278982137,
#  'electr': 3.2188758248682006,
#  'runaway': 6.907755278982137,
#  'locat': 5.521460917862246,
#  'chang': 3.170085660698769,
#  'memori': 4.710530701645918,
#  'sh': 6.907755278982137,
#  'branch': 5.809142990314028,
#  'travel': 3.816712825623821,
#  'bit': 5.115995809754082,
#  'master': 6.907755278982137,
#  'capabl': 5.809142990314028,
#  'qualiti': 5.809142990314028,
#  'leve': 6.907755278982137,
#  'toroid': 5.298317366548036,
#  'summar': 6.907755278982137,
#  'assumpt': 5.521460917862246,
#  'trigonometr': 6.907755278982137,
#  'convers': 4.509860006183766,
#  'dens': 6.214608098422191,
#  'recurr': 5.809142990314028,
#  'concurr': 6.907755278982137,
#  'solut': 3.9633162998156966,
#  'philip': 6.907755278982137,
#  'air': 5.298317366548036,
#  'striae': 6.907755278982137,
#  'posit': 3.7297014486341915,
#  'driver': 6.907755278982137,
#  'introduct': 6.907755278982137,
#  'ioniz': 2.864704011147587,
#  'fluctuat': 3.7722610630529876,
#  'emphas': 6.214608098422191,
#  'fernando': 6.907755278982137,
#  'neutron': 5.115995809754082,
#  'govern': 6.214608098422191,
#  'suppress': 6.214608098422191,
#  'restrict': 5.809142990314028,
#  'associ': 3.7722610630529876,
#  'fring': 6.214608098422191,
#  'vortic': 6.907755278982137,
#  'matric': 5.809142990314028,
#  'board': 5.809142990314028,
#  'spectroscopi': 6.214608098422191,
#  'threse': 6.907755278982137,
#  'fokker': 6.907755278982137,
#  'sansserif': 6.907755278982137,
#  'annular': 6.214608098422191,
#  'brewster': 6.907755278982137,
#  'out': 5.809142990314028,
#  'inner': 4.710530701645918,
#  'season': 4.017383521085972,
#  'washington': 6.214608098422191,
#  'uniform': 4.268697949366879,
#  'neu': 6.907755278982137,
#  'appropri': 6.907755278982137,
#  'anisotrop': 5.521460917862246,
#  'adequ': 6.907755278982137,
#  'understand': 6.907755278982137,
#  'quasihydrodynam': 6.907755278982137,
#  'dynam': 4.710530701645918,
#  'vectori': 6.907755278982137,
#  'employ': 5.298317366548036,
#  'flown': 6.907755278982137,
#  'triod': 6.214608098422191,
#  'audio': 6.907755278982137,
#  'load': 4.710530701645918,
#  'militari': 6.907755278982137,
#  'daili': 5.115995809754082,
#  'fulli': 5.298317366548036,
#  'comment': 5.521460917862246,
#  'unreli': 6.907755278982137,
#  'ink': 6.907755278982137,
#  'treat': 6.214608098422191,
#  'diffract': 4.8283137373023015,
#  'hemispher': 5.115995809754082,
#  'fraction': 6.907755278982137,
#  'satisfi': 6.214608098422191,
#  'perform': 3.8632328412587142,
#  'giten': 6.214608098422191,
#  'worker': 6.907755278982137,
#  'rc': 4.961845129926823,
#  'emitt': 5.298317366548036,
#  'shift': 4.509860006183766,
#  'eleven': 6.907755278982137,
#  'lain': 6.907755278982137,
#  'meteor': 4.268697949366879,
#  'print': 6.214608098422191,
#  'quot': 5.809142990314028,
#  'explor': 5.115995809754082,
#  'act': 5.298317366548036,
#  'evapor': 6.907755278982137,
#  'lowamplitud': 6.907755278982137,
#  'direct': 3.7297014486341915,
#  'pre': 5.809142990314028,
#  'uk': 6.907755278982137,
#  'map': 5.521460917862246,
#  'mismatch': 6.907755278982137,
#  'sky': 5.115995809754082,
#  'tin': 6.907755278982137,
#  'sellmey': 6.907755278982137,
#  'forbush': 5.809142990314028,
#  'explain': 3.8632328412587142,
#  'broad': 6.214608098422191,
#  'chart': 5.809142990314028,
#  'vp': 6.907755278982137,
#  'spectromet': 5.115995809754082,
#  'bomb': 6.214608098422191,
#  'gap': 5.298317366548036,
#  'israel': 6.907755278982137,
#  'entropi': 6.907755278982137,
#  'perseu': 6.907755278982137,
#  'mercuri': 6.907755278982137,
#  'multichannel': 6.907755278982137,
#  'eigenvalu': 6.214608098422191,
#  'hourli': 6.214608098422191,
#  'german': 6.907755278982137,
#  'probe': 4.710530701645918,
#  'develop': 3.2968373663379125,
#  'meet': 5.809142990314028,
#  'metast': 6.907755278982137,
#  'apertur': 5.298317366548036,
#  'key': 6.214608098422191,
#  'invers': 4.961845129926823,
#  'planetari': 5.521460917862246,
#  'concav': 6.214608098422191,
#  'denot': 6.907755278982137,
#  'limit': 4.199705077879927,
#  'heisenberg': 6.214608098422191,
#  'artifici': 4.3428059215206005,
#  'preferenti': 6.907755278982137,
#  'n': 6.214608098422191,
#  'attain': 6.907755278982137,
#  'display': 4.8283137373023015,
#  'semiconduct': 6.907755278982137,
#  'import': 6.907755278982137,
#  'larmor': 6.907755278982137,
#  'russian': 6.907755278982137,
#  'decay': 4.605170185988092,
#  'extrapol': 6.214608098422191,
#  'verifi': 6.214608098422191,
#  'ball': 6.907755278982137,
#  'corresspond': 6.907755278982137,
#  'patch': 6.214608098422191,
#  'megawatt': 6.907755278982137,
#  'everi': 6.214608098422191,
#  'crown': 6.907755278982137,
#  'capacit': 4.268697949366879,
#  'widthmm': 6.907755278982137,
#  'seal': 6.907755278982137,
#  'protonospher': 6.214608098422191,
#  'stark': 6.907755278982137,
#  'close': 4.509860006183766,
#  'prescrib': 6.907755278982137,
#  'analysi': 2.6736487743848776,
#  'dimensionless': 6.907755278982137,
#  'tidal': 6.907755278982137,
#  'antarct': 5.521460917862246,
#  'effici': 4.710530701645918,
#  'significantli': 6.214608098422191,
#  'sudden': 4.710530701645918,
#  'wavelength': 3.912023005428146,
#  'box': 6.907755278982137,
#  'san': 6.907755278982137,
#  'adjust': 5.521460917862246,
#  'connexion': 6.907755278982137,
#  'sever': 3.6888794541139363,
#  'capetown': 6.214608098422191,
#  'subsequ': 6.907755278982137,
#  'aerial': 4.199705077879927,
#  'rutil': 6.214608098422191,
#  'determin': 2.796881414808826,
#  'launch': 5.298317366548036,
#  'diffus': 4.422848629194137,
#  'concern': 5.809142990314028,
#  'criterion': 6.214608098422191,
#  'ionic': 5.521460917862246,
#  'compris': 5.115995809754082,
#  'ambipolar': 6.907755278982137,
#  'irradi': 6.214608098422191,
#  'ascens': 6.907755278982137,
#  'vast': 6.907755278982137,
#  'acceler': 5.298317366548036,
#  'sinc': 6.214608098422191,
#  'vapour': 5.809142990314028,
#  'unwat': 6.907755278982137,
#  'piggott': 6.907755278982137,
#  'nuclei': 6.907755278982137,
#  'genoa': 6.907755278982137,
#  'reiter': 6.907755278982137,
#  'rarefi': 5.809142990314028,
#  'guidanc': 6.907755278982137,
#  'pair': 4.8283137373023015,
#  'toward': 6.214608098422191,
#  'microbarograph': 6.907755278982137,
#  'mutual': 5.809142990314028,
#  'polish': 6.907755278982137,
#  'electrojet': 6.214608098422191,
#  'low': 2.882403588246988,
#  'hf': 5.298317366548036,
#  'serv': 6.907755278982137,
#  'exp': 6.907755278982137,
#  'past': 6.907755278982137,
#  'infrar': 4.8283137373023015,
#  'deal': 6.214608098422191,
#  'instantan': 5.809142990314028,
#  'substanti': 6.907755278982137,
#  'infrequ': 6.907755278982137,
#  'whose': 4.961845129926823,
#  'multipol': 6.907755278982137,
#  'plasma': 2.617295837833746,
#  'tape': 5.115995809754082,
#  'observatori': 5.521460917862246,
#  'output': 3.4420193761824107,
#  'reactanc': 4.422848629194137,
#  'summat': 6.907755278982137,
#  'suscept': 5.521460917862246,
#  'topsid': 6.907755278982137,
#  'electrohydromagnet': 6.907755278982137,
#  'track': 5.521460917862246,
#  'detect': 4.074541934925921,
#  'nonessenti': 6.907755278982137,
#  'veroniqu': 6.907755278982137,
#  'peak': 3.912023005428146,
#  'introduc': 5.521460917862246,
#  'composit': 6.214608098422191,
#  'linear': 3.473768074496991,
#  'rang': 2.882403588246988,
#  'storag': 3.912023005428146,
#  'represent': 5.298317366548036,
#  'filament': 6.907755278982137,
#  'nondevi': 6.907755278982137,
#  'part': -3.6630615210879647,
#  'exhibit': 6.907755278982137,
#  'estim': 4.074541934925921,
#  'ngc': 6.907755278982137,
#  'megaton': 6.907755278982137,
#  'dope': 6.214608098422191,
#  'leakag': 6.214608098422191,
#  'sec': 4.961845129926823,
#  'straight': 5.298317366548036,
#  'configur': 4.8283137373023015,
#  'australian': 6.214608098422191,
#  'baker': 6.907755278982137,
#  'academi': 6.907755278982137,
#  'scienc': 6.907755278982137,
#  'fix': 5.809142990314028,
#  'forc': 4.961845129926823,
#  'infinitesim': 6.907755278982137,
#  'reson': 3.1465551632885744,
#  'aurora': 4.199705077879927,
#  'version': 5.521460917862246,
#  'loop': 4.8283137373023015,
#  'author': 5.521460917862246,
#  'magic': 6.907755278982137,
#  'coat': 5.521460917862246,
#  'miller': 6.907755278982137,
#  'oscillogram': 6.907755278982137,
#  'polar': 3.7722610630529876,
#  'accuraci': 5.298317366548036,
#  'deby': 6.907755278982137,
#  'record': 3.540459448995663,
#  'unz': 6.907755278982137,
#  'geometr': 6.907755278982137,
#  'character': 6.907755278982137,
#  'project': 4.710530701645918,
#  'log': 6.907755278982137,
#  'refriger': 6.907755278982137,
#  'persist': 5.809142990314028,
#  'small': -3.2575964129798,
#  'diamagnet': 5.521460917862246,
#  'stratum': 6.907755278982137,
#  'annul': 6.907755278982137,
#  'dumb': 6.907755278982137,
#  'data': 2.900422093749666,
#  'circuitri': 5.809142990314028,
#  'ward': 6.907755278982137,
#  'via': 6.214608098422191,
#  'deflect': 6.214608098422191,
#  'decemb': 5.521460917862246,
#  'millimetr': 5.521460917862246,
#  'kokobunji': 6.907755278982137,
#  'nyquist': 6.907755278982137,
#  'ghana': 6.907755278982137,
#  'angl': 4.199705077879927,
#  'infer': 5.809142990314028,
#  'harmon': 3.816712825623821,
#  'diminish': 6.907755278982137,
#  'diatom': 6.907755278982137,
#  'rod': 6.214608098422191,
#  'increas': -3.7371694932416863,
#  'nebula': 6.907755278982137,
#  'focus': 5.809142990314028,
#  'control': 3.4420193761824107,
#  'million': 6.907755278982137,
#  'reactor': 6.214608098422191,
#  'field': 1.9449106487222299,
#  'distort': 4.509860006183766,
#  'arc': 5.115995809754082,
#  'assembl': 5.809142990314028,
#  'greatest': 5.521460917862246,
#  'tsumeb': 6.907755278982137,
#  'instal': 6.214608098422191,
#  'converg': 5.809142990314028,
#  'experi': -3.218375699826519,
#  'planet': 6.907755278982137,
#  'explicit': 5.521460917862246,
#  'strip': 5.809142990314028,
#  'lie': 5.809142990314028,
#  'allen': 4.422848629194137,
#  'inadequaci': 6.907755278982137,
#  'union': 6.907755278982137,
#  'plate': 4.8283137373023015,
#  'astabl': 6.214608098422191,
#  'unilater': 6.907755278982137,
#  'convect': 6.907755278982137,
#  'build': -1.6089377873924189,
#  'meta': 6.907755278982137,
#  'allow': 5.115995809754082,
#  'perpendicular': 5.809142990314028,
#  'g': 6.907755278982137,
#  'id': 5.809142990314028,
#  'slightli': 5.298317366548036,
#  'mill': 6.214608098422191,
#  'fluid': 6.214608098422191,
#  'chamber': 6.907755278982137,
#  'spitzer': 6.907755278982137,
#  'common': 5.521460917862246,
#  'passag': 5.809142990314028,
#  'script': 6.907755278982137,
#  'zeta': 6.907755278982137,
#  'bidirect': 6.214608098422191,
#  'maxima': 6.214608098422191,
#  'thermonuclear': 6.907755278982137,
#  'transformerless': 6.214608098422191,
#  'trigonometri': 6.907755278982137,
#  'barium': 6.907755278982137,
#  'report': 3.7297014486341915,
#  'view': 6.907755278982137,
#  'electromechan': 5.809142990314028,
#  'relat': 3.123565645063876,
#  'cone': 6.907755278982137,
#  'neutral': 4.509860006183766,
#  'bremsstrahlung': 6.907755278982137,
#  'inaugur': 6.907755278982137,
#  'activ': 3.3524072174927233,
#  'diagnost': 6.907755278982137,
#  'strain': 6.907755278982137,
#  'northward': 6.907755278982137,
#  'enough': 6.907755278982137,
#  'larg': 3.473768074496991,
#  'argu': 6.907755278982137,
#  'bias': 6.907755278982137,
#  'natur': 4.961845129926823,
#  'rectifi': 4.605170185988092,
#  'arctic': 6.214608098422191,
#  'decim': 6.214608098422191,
#  'head': 5.521460917862246,
#  'knowledg': 6.214608098422191,
#  'mid': 6.214608098422191,
#  'virtual': 5.809142990314028,
#  'input': 4.199705077879927,
#  'disadvantag': 6.214608098422191,
#  'slight': 6.214608098422191,
#  'proceed': 6.907755278982137,
#  'emf': 6.214608098422191,
#  'ellipsoid': 6.214608098422191,
#  'typic': 5.115995809754082,
#  'bandyopadhyay': 6.907755278982137,
#  'unprotect': 6.907755278982137,
#  'rico': 6.214608098422191,
#  'godley': 6.907755278982137,
#  'nonblanket': 6.907755278982137,
#  'hydromagnet': 4.509860006183766,
#  'often': 6.907755278982137,
#  'l': 5.809142990314028,
#  'ssc': 6.907755278982137,
#  'invalid': 6.214608098422191,
#  'paper': 4.509860006183766,
#  'move': 4.605170185988092,
#  'neumann': 6.907755278982137,
#  'affect': 6.214608098422191,
#  'confer': 6.907755278982137,
#  'would': 5.298317366548036,
#  'examin': 3.575550768806933,
#  'recoveri': 5.809142990314028,
#  'flip': 5.298317366548036,
#  'grade': 6.907755278982137,
#  'microwav': 3.540459448995663,
#  'degrad': 6.907755278982137,
#  'side': 5.115995809754082,
#  'hall': 5.298317366548036,
#  'live': 6.214608098422191,
#  'shaft': 6.907755278982137,
#  'music': 6.907755278982137,
#  'appendic': 6.907755278982137,
#  'properti': 3.7297014486341915,
#  'abil': 6.907755278982137,
#  'nonrevers': 6.907755278982137,
#  'even': 5.809142990314028,
#  'area': 5.521460917862246,
#  'collis': 3.816712825623821,
#  'highest': 6.214608098422191,
#  'parker': 6.907755278982137,
#  'hamiltonian': 6.214608098422191,
#  'delay': 4.422848629194137,
#  'dualiti': 6.214608098422191,
#  'start': 6.907755278982137,
#  'bunch': 5.809142990314028,
#  'byrn': 6.907755278982137,
#  'bright': 5.809142990314028,
#  'decreas': 3.816712825623821,
#  'ten': 5.521460917862246,
#  'longitud': 6.214608098422191,
#  'overlap': 6.907755278982137,
#  'africa': 5.809142990314028,
#  'insid': 5.809142990314028,
#  'asiago': 6.907755278982137,
#  'rarifi': 6.907755278982137,
#  'tripl': 6.214608098422191,
#  'veloc': 4.074541934925921,
#  'soviet': 5.298317366548036,
#  'lowest': 6.907755278982137,
#  'stainless': 6.907755278982137,
#  'offset': 6.907755278982137,
#  'edg': 6.214608098422191,
#  'preamplifi': 6.907755278982137,
#  'metaast': 0.0005001250416816205,
#  'februari': 5.809142990314028,
#  'minimum': 4.199705077879927,
#  'thick': 4.8283137373023015,
#  'summer': 5.521460917862246,
#  'jupit': 5.521460917862246,
#  'doppler': 5.115995809754082,
#  'geocyclotron': 6.907755278982137,
#  'lecher': 6.214608098422191,
#  'applic': 2.703062659591171,
#  'element': 3.3524072174927233,
#  ...}

# %% [markdown]
# getting total doc rsv score

# %%
#calculates the rsv of a document based on the query provided
def generate_doc_rsv(file_name, query):
  result = 0
  doc_list = data[data["file_name"] == file_name]["text"]
  for doc in doc_list:
    for word in doc:
      if word in query:
        result += weights[word]
  return result

# %% [markdown]
# rank docs by query provided

# %%
#retreive all docs containing our word
#get the rsv score of the retrieved docs
def rank_docs(query):
  results = {
      'file_name': [],
      'score': []
  }
  docs = list()
  for word in query:
    docs = [*docs, *list(word_dict[word])]
  for file_name in docs:
    results['file_name'].append(file_name)
    results['score'].append(generate_doc_rsv(file_name, query))
  results = pd.DataFrame(results).sort_values('score', ascending=False)
  return results

# %% [markdown]
# # search results/ prediction

# %%
#preprocess the query first then rank
def search_query(search_query, retrieved_docs = 10):
  #tokenize query
  query = list(tokenize([search_query]))[0]
  #lower case
  query = [txt.lower() for txt in query]
  #stop words
  query = [txt for txt in query if not txt in stop_words]
  #stemming
  query = [porter_stemmer.stem(txt) for txt in query]
  return rank_docs(query).head(retrieved_docs)

# %% [markdown]
# get the query

# %%
query_path = "/content/gdrive/MyDrive/data/HW04/query.txt"
query = pd.read_csv(query_path, names=["query"], sep=",", header=None)
query.head()
# Out:
#                                                query
# 0  secondary emission of electrons by positive io...

# %% [markdown]
# get first top 10 results

# %%
result = search_query(query["query"][0], 10)
result
# Out:
#       file_name     score
# 212  file_10965  7.459403
# 197  file_11118  7.459403
# 191  file_10261  7.459403
# 190  file_10328  7.459403
# 245  file_10869  6.214608
# 205  file_10048  3.729701
# 210  file_10786  3.729701
# 209  file_10012  3.729701
# 207  file_11236  3.729701
# 206  file_10353  3.729701
